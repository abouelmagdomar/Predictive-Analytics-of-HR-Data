# %%
import requests
from bs4 import BeautifulSoup
import csv
import re

categories = [
    "golden_palm",
    "grand_prix",
    "international_jury_prize",
    "best_director",
    "best_actor",
    "best_actress",
    "best_supporting_actor",
    "best_supporting_actress",
    "best_screenplay",
    "best_art_direction",
    "best_cinematography",
    "best_music",
    "best_artistic_contribution",
    "special_mention",
    "international_prize",
    "fipresci",
    "camera_d_or",
    "special_golden_palm",
    "best_color",
    "best_animation_design",
    "best_romantic_documentary",
    "best_human_document",
    "best_social_film",
    "best_psychological_love_film",
    "best_poetic_humor",
    "best_adventure_crime_film",
    "best_musical_comedy",
    "best_lyrical_film",
    "jury_prize",
    "special_jury_prize",
    "prize_ecumenical",
    "prize_ecumenical_mention",
    "artist_technician_prize",
    "technical_grand_prize",
    "special_award",
    "young_cinema_award",
    "audience_award",
    "ocic_award",
    "ocic_award_special_mention",
    "best_short_film",
    "short_film_jury_prize",
    "best_documentary_short_film",
    "international_peace_award",
    "un_certain_regard_best_film",
    "un_certain_regard_jury_prize",
    "un_certain_regard_special_distinction",
    "un_certain_regard_poetic_narrative",
    "un_certain_regard_directing_prize",
    "un_certain_regard_screenplay",
    "un_certain_regard_best_performance",
    "un_certain_regard_best_actress",
    "un_certain_regard_best_actor",
    "un_certain_regard_best_cast",
    "un_certain_regard_fipresci",
    "un_certain_regard_jurys_coup_de_coeur",
    "critics_week_grand_prize",
    "75anniversary",
    "premiere",
    "special_screenings",
    "midnight_screenings",
    "best_european_film_quinzaine"
]

def remove_text_in_parentheses(text):
    text = re.sub(r'\([^)]*\)', '', text)
    text = re.sub(r"'[^']*'", '', text)
    text = re.sub(r'"[^"]*"', '', text)
    return text.strip()

def scrape_winners(cat_id):
    url = f"https://www.filmaffinity.com/en/awards-history.php?cat-id=cannes_{cat_id}"
    try:
        response = requests.get(url)
        response.raise_for_status()  # Raise an exception for bad status codes
    except requests.exceptions.RequestException as e:
        print(f"Error fetching URL for category {cat_id}: {e}")
        return []

    soup = BeautifulSoup(response.text, 'html.parser')

    # Find the wrapper with the awards
    wrapper = soup.find('div', {'class': 'wrapper'})

    # Check if the wrapper was found
    if wrapper is None:
        print(f"Error: Couldn't find a wrapper with class 'wrapper' for category {cat_id}")
        return []

    # Find all the list items in the wrapper
    list_items = wrapper.find_all('li', class_=lambda x: x != 'empty-box')

    # Extract the information from each list item
    winners = []
    for item in list_items:
        year_elem = item.find('div', {'class': 'year'})
        movie_title_elem = item.find('span', {'class': 'movie-title-link'})
        director_elem = item.find('div', {'class': 'director'})
        cast_elem = item.find('div', {'class': 'cast'})
        
        if year_elem and movie_title_elem and director_elem and cast_elem:
            year = year_elem.text.strip()
            movie_title = movie_title_elem.text.strip()
            # Remove text within parentheses and quotation marks from the movie title
            movie_title = remove_text_in_parentheses(movie_title)
            director = director_elem.text.strip()
            cast = cast_elem.text.strip()
            winners.append([year, movie_title, director, cast])

    return winners

# Loop through all the categories and scrape the winners
with open('cannes_film_affinity_winners.csv', 'w', newline='', encoding='utf-8') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['Category', 'Year', 'Movie Title', 'Director', 'Cast'])

    for cat_id in categories:
        winners = scrape_winners(cat_id)
        for winner in winners:
            writer.writerow(winner)
# Out:
# Error fetching URL for category prize_ecumenical: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))

# %%
import requests
from bs4 import BeautifulSoup
import csv
import re

urls = [
"https://www.filmaffinity.com/en/awards-history.php?cat-id=moscow_best_actress",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=moscow_special_mention",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=moscow_best_documentary",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=moscow_special_prize",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=moscow_audience_award",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=moscow_fipresci_prize",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=moscow_russian_critics_award",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=moscow_best_short_film",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=moscow_best_film_perspectives",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=moscow_special_mention_perspectives",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=roma_best_film",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=roma_grand_jury_award",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=roma_special_jury_award",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=roma_best_director",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=roma_best_actress",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=roma_best_actor",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=roma_best_screenplay",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=roma_best_original_score",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=roma_audience_award",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=roma_best_newcomer",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=roma_best_technical_contribution",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=roma_best_debut",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=roma_best_documentary",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=gijon_mejor_pelicula",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=gijon_mejor_pelicula_retueyos",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=gijon_mejor_pelicula_albar",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=gijon_mejor_pelicula_trance",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=gijon_mejor_director",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=gijon_mejor_actriz",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=gijon_mejor_actor",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=gijon_premio_distribucion",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=gijon_premio_especial_jurado",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=gijon_special_jury_mention",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=gijon_mejor_guion",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=gijon_mejor_fotografia",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=gijon_mejor_banda_sonora",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=gijon_mejor_direccion_artistica",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=gijon_premio_fipresci",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=gijon_young_jury_prize_best_film",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=gijon_best_animation_film",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=gijon_audience_award",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=gijon_audience_award_tierres_en_trance",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=gijon_premio_europa_film_festivals",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=gijon_premio_enfants_terribles",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=gijon_best_short",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=gijon_best_short_special_mention",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_best_film",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_special_jury_prize",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_best_director",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_best_Director_second_prize",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_best_actor",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_best_actor_second_prize",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_best_actress",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_interpretation",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_most_promising_actor",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_special_mention",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_best_screenplay",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_best_cinematography",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_best_bw_cinematography",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_best_color_cinematography",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_cineasti_del_presente_best_film",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_cineasti_del_presente_special_jury_prize",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_cineasti_del_presente_emerging_director",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_cineasti_del_presente_best_actress",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_cineasti_del_presente_best_actor",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_cineasti_del_presente_special_mention",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_arrangement_prize",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_audience_award",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_variety_award",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_pardo_verde",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_pardo_verde_special_mention",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_pardo_verde_special_mention_short",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_funniest_film_prize",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_role_of_composition",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_best_first_feature",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_best_first_feature_mention",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_swiss_federation",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_fipresci",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_europa_cinemas_label_award",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_ecumenical_award",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_ecumenical_mention",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_best_short_film",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_best_animation_short_film",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=sundance_grand_jury_drama",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=sundance_grand_jury_documentary",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=sundance_grand_jury_world_dramatic",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=sundance_grand_jury_world_doc",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=sundance_best_ensemble",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=sundance_audience_dramatic",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=sundance_audience_documentary",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=sundance_world_audience_dramatic",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=sundance_world_audience_doc",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=sundance_directing_award_dramatic",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=sundance_directing_award_documentary",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=sundance_directing_world_dramatic",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=sundance_directing_world_documentary",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=sundance_screenwriting_award",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=sundance_screenwriting_world_award",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=sundance_cinematography_dramatic",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=sundance_cinematography_documentary",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=sundance_cinematography_world_dramatic",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=sundance_cinematography_world_doc",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=sundance_documentary_editing",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=sundance_documentary_world_editing",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=sundance_special_jury_world_dramatic",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=sundance_special_jury_world_doc",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=sundance_special_jury_dramatic",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=sundance_special_jury_documentary",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=sundance_special_jury_world_acting",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=sundance_special_jury_world_breakout",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=sundance_special_jury_us_breakthrough",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=sundance_special_jury_breakthrough_director",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=sundance_special_jury_world_music",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=sundance_special_jury_us_doc_sound",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=sundance_special_jury_world_doc_craft",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=sundance_special_jury_cinematic_innovation",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=sundance_short_film_grand_jury",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=sundance_festival_favorite_award",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=sundance_alfred_p_sloan_prize",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=sundance_special_jury_neorealism",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=tribeca_best_us_narrative_feature",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=tribeca_best_actress_us_narrative",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=tribeca_best_actor_us_narrative",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=tribeca_best_screenplay_us",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=tribeca_best_cinematography_us",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=tribeca_best_narrative_feature",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=tribeca_special_jury_mention",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=tribeca_Best_actress",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=tribeca_best_actor",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=tribeca_best_performance",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=tribeca_best_screenplay",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=tribeca_best_cinematography",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=tribeca_best_editing",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=tribeca_best_new_director",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=tribeca_best_international_narrative_feature",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=tribeca_best_screenplay_international",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=tribeca_best_cinematography_international",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=tribeca_best_actress_international_narrative",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=tribeca_best_actor_international_narrative",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=tribeca_best_performance_international",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=tribeca_best_documentary_feature",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=tribeca_special_jury_mention_doc",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=tribeca_best_new_documentary_director",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=tribeca_best_cinematography_doc",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=tribeca_best_editing_doc",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=tribeca_best_documentary_short",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=tribeca_student_visionary_award",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=tribeca_best_narrative_short",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=tribeca_best_animated_short",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=tribeca_best_international_narrative_short",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=tribeca_best_international_animated_short",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=tribeca_best_music_video",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=seminci_best_picture",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=seminci_silver_spike",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=seminci_jury_prize",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=seminci_special_mention",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=seminci_best_director",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=seminci_best_actor",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=seminci_best_actress",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=seminci_best_new_director",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=seminci_best_script",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=seminci_best_music",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=seminci_best_cinematographer",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=seminci_best_editing",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=seminci_fipresci",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=seminci_best_short_film",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=seminci_silver_spike_short_film",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=seminci_best_european_short_film",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=seminci_audience_award",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=seminci_best_iberoamerican_film",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=seminci_young_seminci",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=seminci_sociograph_award",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=seminci_best_picture",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=seminci_silver_spike",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=seminci_jury_prize",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=seminci_special_mention",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=seminci_best_director",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=seminci_best_actor",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=seminci_best_actress",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=seminci_best_new_director",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=seminci_best_script",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=seminci_best_music",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=seminci_best_cinematographer",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=seminci_best_editing",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=seminci_fipresci",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=seminci_best_short_film",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=seminci_silver_spike_short_film",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=seminci_best_european_short_film",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=seminci_audience_award",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=seminci_best_iberoamerican_film",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=seminci_young_seminci",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=seminci_sociograph_award",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=malaga_best_film",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=malaga_special_jury_prize",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=malaga_best_latin_american_film",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=malaga_best_direction",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=malaga_best_actor",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=malaga_best_actress",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=malaga_best_supporting_actor",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=malaga_best_supporting_actress",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=malaga_best_screenplay",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=malaga_best_new_screenplay",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=malaga_best_soundtrack",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=malaga_best_cinematography",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=malaga_best_editing",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=malaga_best_costume_design",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=malaga_best_make_up",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=malaga_special_mention_jury",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=malaga_critics_award",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=malaga_audience_award",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=malaga_best_shortfilm",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=malaga_best_shortfilm_mention",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=malaga_best_shortfilm_direction",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=malaga_best_shortfilm_actress",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=malaga_best_shortfilm_actor",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=malaga_best_shortfilm_audience",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=sevilla_best_gold_film",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=sevilla_best_silver_film",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=sevilla_special_jury_prize",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=sevilla_best_direction",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=sevilla_best_actor",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=sevilla_best_actress",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=sevilla_best_screenplay",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=sevilla_best_cinematography",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=sevilla_best_editing",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=sevilla_best_sound",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=sevilla_special_mention",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=sevilla_best_first_film",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=sevilla_audience_award",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=sevilla_best_documentary",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=sevilla_special_mention_doc",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=sevilla_critics_award",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=sevilla_campus_jury_award",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=sevilla_eurimages_prize",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=sevilla_rtva_prize",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=chicago_gold_hugo",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=chicago_gold_hugo_foreign_language_film",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=chicago_silver_hugo_jury_prize",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=chicago_silver_hugo_best_director",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=chicago_silver_hugo_best_screenplay",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=chicago_silver_hugo_best_performance",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=chicago_silver_hugo_best_actor",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=chicago_silver_hugo_best_actress",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=chicago_silver_hugo_best_ensemble_performance",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=chicago_silver_hugo_best_cinematography",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=chicago_honorable_mention",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=chicago_silver_hugo_best_sound",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=chicago_silver_hugo_best_art_direction",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=chicago_best_short_film",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=chicago_best_documentary",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=hamptons_best_film",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=hamptons_honorable_mention_film",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=hamptons_best_documentary",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=hamptons_honorable_mention_documentary",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=hamptons_narrative_jury_winner",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=hamptons_documentary_jury_winner",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=hamptons_special_recognition_breakthrough",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=hamptons_award_films_conflict_resolution",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=hamptons_best_short_film",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=hamptons_best_short_documentary",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=hamptons_audience_award_film",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=hamptons_audience_award_documentary",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=hamptons_audience_award_short_film",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=rotterdam_best_film",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=rotterdam_special_jury_award",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=rotterdam_fipresci",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=rotterdam_netpac_award",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=rotterdam_young_jury_award",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=rotterdam_best_short_film",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=rotterdam_vpro_big_screen_award",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=habana_best_film",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=habana_special_jury_prize",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=habana_best_director",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=habana_second_prize",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=habana_third_prize",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=habana_special_mention",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=habana_best_actress",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=habana_best_actor",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=habana_best_screenplay",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=habana_best_cinematography",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=habana_best_art_direction",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=habana_best_editing",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=habana_best_music",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=habana_best_film_music",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=habana_best_sound_mixing",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=habana_best_short_film",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=habana_best_debut",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=habana_best_documentary_feature",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=habana_best_documentary_short",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=habana_best_documentary_special_jury",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=habana_best_animated_feature",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=habana_best_animated_short",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=habana_best_animated_special_jury",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=habana_fipresci",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=habana_audience_award",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=habana_signis_award",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=habana_best_debut_special_prize",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=habana_best_debut_artistic_contribution",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=montreal_best_film",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=montreal_special_grand_prix",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=montreal_best_director",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=montreal_best_actress",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=montreal_best_actor",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=montreal_best_screenplay",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=montreal_best_artistic_contribution",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=montreal_innovation_award",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=montreal_special_prix",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=montreal_jury_prize",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=montreal_best_canadian_film",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=montreal_grand_prix_special",
"https://www.filmaffinity.com/en/awards-history.php?cat-id=montreal_most_popular_film",
]


def remove_text_in_parentheses(text):
    # Remove text within parentheses
    text = re.sub(r'\([^)]*\)', '', text)
    # Remove text within single quotes
    text = re.sub(r"'[^']*'", '', text)
    # Remove text within double quotes
    text = re.sub(r'"[^"]*"', '', text)
    return text.strip()

def get_category_and_city_from_url(url):
    match = re.search(r'cat-id=([a-zA-Z]+)_([a-zA-Z_]+)', url)
    if match:
        city = match.group(1).capitalize()
        category = match.group(2).replace("_", " ").title()
        return city, category
    else:
        return None, None

def scrape_winners(urls):
    all_winners = []
    
    for url in urls:
        city, category = get_category_and_city_from_url(url)
        
        try:
            response = requests.get(url)
            response.raise_for_status()
        except requests.exceptions.RequestException as e:
            print(f"Error fetching URL: {url}, {e}")
            continue

        soup = BeautifulSoup(response.text, 'html.parser')

        wrapper = soup.find('div', {'class': 'wrapper'})

        if wrapper is None:
            print(f"Error: Couldn't find a wrapper with class 'wrapper' for URL: {url}")
            continue

        list_items = wrapper.find_all('li', class_=lambda x: x != 'empty-box')

        for item in list_items:
            year_elem = item.find('div', {'class': 'year'})
            movie_title_elem = item.find('span', {'class': 'movie-title-link'})
            director_elem = item.find('div', {'class': 'director'})
            cast_elem = item.find('div', {'class': 'cast'})
            
            if year_elem and movie_title_elem and director_elem and cast_elem:
                year = year_elem.text.strip()
                movie_title = movie_title_elem.text.strip()
                movie_title = remove_text_in_parentheses(movie_title)
                director = director_elem.text.strip()
                cast = cast_elem.text.strip()
                all_winners.append([city, category, year, movie_title, director, cast])

    return all_winners


# Scrape winners from the URLs
winners = scrape_winners(urls)

# Write the winners to a CSV file
with open('all_film_affinity_winners.csv', 'w', newline='', encoding='utf-8') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['City', 'Category', 'Year', 'Movie Title', 'Director', 'Cast'])

    for winner in winners:
        writer.writerow(winner)
# Out:
# Error fetching URL: https://www.filmaffinity.com/en/awards-history.php?cat-id=moscow_best_actress, 429 Client Error: Too Many Requests for url: https://www.filmaffinity.com/en/awards-history.php?cat-id=moscow_best_actress
# Error fetching URL: https://www.filmaffinity.com/en/awards-history.php?cat-id=moscow_special_mention, 429 Client Error: Too Many Requests for url: https://www.filmaffinity.com/en/awards-history.php?cat-id=moscow_special_mention
# Error fetching URL: https://www.filmaffinity.com/en/awards-history.php?cat-id=moscow_best_documentary, 429 Client Error: Too Many Requests for url: https://www.filmaffinity.com/en/awards-history.php?cat-id=moscow_best_documentary
# Error fetching URL: https://www.filmaffinity.com/en/awards-history.php?cat-id=moscow_special_prize, 429 Client Error: Too Many Requests for url: https://www.filmaffinity.com/en/awards-history.php?cat-id=moscow_special_prize
# Error fetching URL: https://www.filmaffinity.com/en/awards-history.php?cat-id=moscow_audience_award, 429 Client Error: Too Many Requests for url: https://www.filmaffinity.com/en/awards-history.php?cat-id=moscow_audience_award
# Error fetching URL: https://www.filmaffinity.com/en/awards-history.php?cat-id=moscow_fipresci_prize, 429 Client Error: Too Many Requests for url: https://www.filmaffinity.com/en/awards-history.php?cat-id=moscow_fipresci_prize
# Error fetching URL: https://www.filmaffinity.com/en/awards-history.php?cat-id=moscow_russian_critics_award, 429 Client Error: Too Many Requests for url: https://www.filmaffinity.com/en/awards-history.php?cat-id=moscow_russian_critics_award
# Error fetching URL: https://www.filmaffinity.com/en/awards-history.php?cat-id=moscow_best_short_film, 429 Client Error: Too Many Requests for url: https://www.filmaffinity.com/en/awards-history.php?cat-id=moscow_best_short_film
# Error fetching URL: https://www.filmaffinity.com/en/awards-history.php?cat-id=moscow_best_film_perspectives, 429 Client Error: Too Many Requests for url: https://www.filmaffinity.com/en/awards-history.php?cat-id=moscow_best_film_perspectives
# Error fetching URL: https://www.filmaffinity.com/en/awards-history.php?cat-id=moscow_special_mention_perspectives, 429 Client Error: Too Many Requests for url: https://www.filmaffinity.com/en/awards-history.php?cat-id=moscow_special_mention_perspectives
# Error fetching URL: https://www.filmaffinity.com/en/awards-history.php?cat-id=roma_best_film, 429 Client Error: Too Many Requests for url: https://www.filmaffinity.com/en/awards-history.php?cat-id=roma_best_film
# Error fetching URL: https://www.filmaffinity.com/en/awards-history.php?cat-id=roma_grand_jury_award, 429 Client Error: Too Many Requests for url: https://www.filmaffinity.com/en/awards-history.php?cat-id=roma_grand_jury_award
# Error fetching URL: https://www.filmaffinity.com/en/awards-history.php?cat-id=roma_special_jury_award, 429 Client Error: Too Many Requests for url: https://www.filmaffinity.com/en/awards-history.php?cat-id=roma_special_jury_award
# Error fetching URL: https://www.filmaffinity.com/en/awards-history.php?cat-id=roma_best_director, 429 Client Error: Too Many Requests for url: https://www.filmaffinity.com/en/awards-history.php?cat-id=roma_best_director
# Error fetching URL: https://www.filmaffinity.com/en/awards-history.php?cat-id=roma_best_actress, 429 Client Error: Too Many Requests for url: https://www.filmaffinity.com/en/awards-history.php?cat-id=roma_best_actress
# Error fetching URL: https://www.filmaffinity.com/en/awards-history.php?cat-id=roma_best_actor, 429 Client Error: Too Many Requests for url: https://www.filmaffinity.com/en/awards-history.php?cat-id=roma_best_actor
# Error fetching URL: https://www.filmaffinity.com/en/awards-history.php?cat-id=roma_best_screenplay, 429 Client Error: Too Many Requests for url: https://www.filmaffinity.com/en/awards-history.php?cat-id=roma_best_screenplay
# Error fetching URL: https://www.filmaffinity.com/en/awards-history.php?cat-id=roma_best_original_score, 429 Client Error: Too Many Requests for url: https://www.filmaffinity.com/en/awards-history.php?cat-id=roma_best_original_score
# Error fetching URL: https://www.filmaffinity.com/en/awards-history.php?cat-id=roma_audience_award, 429 Client Error: Too Many Requests for url: https://www.filmaffinity.com/en/awards-history.php?cat-id=roma_audience_award
# Error fetching URL: https://www.filmaffinity.com/en/awards-history.php?cat-id=roma_best_newcomer, 429 Client Error: Too Many Requests for url: https://www.filmaffinity.com/en/awards-history.php?cat-id=roma_best_newcomer
# Error fetching URL: https://www.filmaffinity.com/en/awards-history.php?cat-id=roma_best_technical_contribution, 429 Client Error: Too Many Requests for url: https://www.filmaffinity.com/en/awards-history.php?cat-id=roma_best_technical_contribution
# Error fetching URL: https://www.filmaffinity.com/en/awards-history.php?cat-id=roma_best_debut, 429 Client Error: Too Many Requests for url: https://www.filmaffinity.com/en/awards-history.php?cat-id=roma_best_debut
# Error fetching URL: https://www.filmaffinity.com/en/awards-history.php?cat-id=roma_best_documentary, 429 Client Error: Too Many Requests for url: https://www.filmaffinity.com/en/awards-history.php?cat-id=roma_best_documentary
# Error fetching URL: https://www.filmaffinity.com/en/awards-history.php?cat-id=gijon_mejor_pelicula, 429 Client Error: Too Many Requests for url: https://www.filmaffinity.com/en/awards-history.php?cat-id=gijon_mejor_pelicula
# Error fetching URL: https://www.filmaffinity.com/en/awards-history.php?cat-id=gijon_mejor_pelicula_retueyos, 429 Client Error: Too Many Requests for url: https://www.filmaffinity.com/en/awards-history.php?cat-id=gijon_mejor_pelicula_retueyos
# Error fetching URL: https://www.filmaffinity.com/en/awards-history.php?cat-id=gijon_mejor_pelicula_albar, 429 Client Error: Too Many Requests for url: https://www.filmaffinity.com/en/awards-history.php?cat-id=gijon_mejor_pelicula_albar
# Error fetching URL: https://www.filmaffinity.com/en/awards-history.php?cat-id=gijon_mejor_pelicula_trance, 429 Client Error: Too Many Requests for url: https://www.filmaffinity.com/en/awards-history.php?cat-id=gijon_mejor_pelicula_trance
# Error fetching URL: https://www.filmaffinity.com/en/awards-history.php?cat-id=gijon_mejor_director, 429 Client Error: Too Many Requests for url: https://www.filmaffinity.com/en/awards-history.php?cat-id=gijon_mejor_director
# Error fetching URL: https://www.filmaffinity.com/en/awards-history.php?cat-id=gijon_mejor_actriz, 429 Client Error: Too Many Requests for url: https://www.filmaffinity.com/en/awards-history.php?cat-id=gijon_mejor_actriz
# Error fetching URL: https://www.filmaffinity.com/en/awards-history.php?cat-id=gijon_mejor_actor, 429 Client Error: Too Many Requests for url: https://www.filmaffinity.com/en/awards-history.php?cat-id=gijon_mejor_actor
# Error fetching URL: https://www.filmaffinity.com/en/awards-history.php?cat-id=gijon_premio_distribucion, 429 Client Error: Too Many Requests for url: https://www.filmaffinity.com/en/awards-history.php?cat-id=gijon_premio_distribucion
# Error fetching URL: https://www.filmaffinity.com/en/awards-history.php?cat-id=gijon_premio_especial_jurado, 429 Client Error: Too Many Requests for url: https://www.filmaffinity.com/en/awards-history.php?cat-id=gijon_premio_especial_jurado
# Error fetching URL: https://www.filmaffinity.com/en/awards-history.php?cat-id=gijon_special_jury_mention, 429 Client Error: Too Many Requests for url: https://www.filmaffinity.com/en/awards-history.php?cat-id=gijon_special_jury_mention
# Error fetching URL: https://www.filmaffinity.com/en/awards-history.php?cat-id=gijon_mejor_guion, 429 Client Error: Too Many Requests for url: https://www.filmaffinity.com/en/awards-history.php?cat-id=gijon_mejor_guion
# Error fetching URL: https://www.filmaffinity.com/en/awards-history.php?cat-id=gijon_mejor_fotografia, 429 Client Error: Too Many Requests for url: https://www.filmaffinity.com/en/awards-history.php?cat-id=gijon_mejor_fotografia
# Error fetching URL: https://www.filmaffinity.com/en/awards-history.php?cat-id=gijon_mejor_banda_sonora, 429 Client Error: Too Many Requests for url: https://www.filmaffinity.com/en/awards-history.php?cat-id=gijon_mejor_banda_sonora
# Error fetching URL: https://www.filmaffinity.com/en/awards-history.php?cat-id=gijon_mejor_direccion_artistica, 429 Client Error: Too Many Requests for url: https://www.filmaffinity.com/en/awards-history.php?cat-id=gijon_mejor_direccion_artistica
# Error fetching URL: https://www.filmaffinity.com/en/awards-history.php?cat-id=gijon_premio_fipresci, 429 Client Error: Too Many Requests for url: https://www.filmaffinity.com/en/awards-history.php?cat-id=gijon_premio_fipresci
# Error fetching URL: https://www.filmaffinity.com/en/awards-history.php?cat-id=gijon_young_jury_prize_best_film, 429 Client Error: Too Many Requests for url: https://www.filmaffinity.com/en/awards-history.php?cat-id=gijon_young_jury_prize_best_film
# Error fetching URL: https://www.filmaffinity.com/en/awards-history.php?cat-id=gijon_best_animation_film, 429 Client Error: Too Many Requests for url: https://www.filmaffinity.com/en/awards-history.php?cat-id=gijon_best_animation_film
# Error fetching URL: https://www.filmaffinity.com/en/awards-history.php?cat-id=gijon_audience_award, 429 Client Error: Too Many Requests for url: https://www.filmaffinity.com/en/awards-history.php?cat-id=gijon_audience_award
# Error fetching URL: https://www.filmaffinity.com/en/awards-history.php?cat-id=gijon_audience_award_tierres_en_trance, 429 Client Error: Too Many Requests for url: https://www.filmaffinity.com/en/awards-history.php?cat-id=gijon_audience_award_tierres_en_trance
# Error fetching URL: https://www.filmaffinity.com/en/awards-history.php?cat-id=gijon_premio_europa_film_festivals, 429 Client Error: Too Many Requests for url: https://www.filmaffinity.com/en/awards-history.php?cat-id=gijon_premio_europa_film_festivals
# Error fetching URL: https://www.filmaffinity.com/en/awards-history.php?cat-id=gijon_premio_enfants_terribles, 429 Client Error: Too Many Requests for url: https://www.filmaffinity.com/en/awards-history.php?cat-id=gijon_premio_enfants_terribles
# Error fetching URL: https://www.filmaffinity.com/en/awards-history.php?cat-id=gijon_best_short, 429 Client Error: Too Many Requests for url: https://www.filmaffinity.com/en/awards-history.php?cat-id=gijon_best_short
# Error fetching URL: https://www.filmaffinity.com/en/awards-history.php?cat-id=gijon_best_short_special_mention, 429 Client Error: Too Many Requests for url: https://www.filmaffinity.com/en/awards-history.php?cat-id=gijon_best_short_special_mention
# Error fetching URL: https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_best_film, 429 Client Error: Too Many Requests for url: https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_best_film
# Error fetching URL: https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_special_jury_prize, 429 Client Error: Too Many Requests for url: https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_special_jury_prize
# Error fetching URL: https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_best_director, 429 Client Error: Too Many Requests for url: https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_best_director
# Error fetching URL: https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_best_Director_second_prize, 429 Client Error: Too Many Requests for url: https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_best_Director_second_prize
# Error fetching URL: https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_best_actor, 429 Client Error: Too Many Requests for url: https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_best_actor
# Error fetching URL: https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_best_actor_second_prize, 429 Client Error: Too Many Requests for url: https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_best_actor_second_prize
# Error fetching URL: https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_best_actress, 429 Client Error: Too Many Requests for url: https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_best_actress
# Error fetching URL: https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_interpretation, 429 Client Error: Too Many Requests for url: https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_interpretation
# Error fetching URL: https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_most_promising_actor, 429 Client Error: Too Many Requests for url: https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_most_promising_actor
# Error fetching URL: https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_special_mention, 429 Client Error: Too Many Requests for url: https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_special_mention
# Error fetching URL: https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_best_screenplay, 429 Client Error: Too Many Requests for url: https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_best_screenplay
# Error fetching URL: https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_best_cinematography, 429 Client Error: Too Many Requests for url: https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_best_cinematography
# Error fetching URL: https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_best_bw_cinematography, 429 Client Error: Too Many Requests for url: https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_best_bw_cinematography
# Error fetching URL: https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_best_color_cinematography, 429 Client Error: Too Many Requests for url: https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_best_color_cinematography
# Error fetching URL: https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_cineasti_del_presente_best_film, 429 Client Error: Too Many Requests for url: https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_cineasti_del_presente_best_film
# Error fetching URL: https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_cineasti_del_presente_special_jury_prize, 429 Client Error: Too Many Requests for url: https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_cineasti_del_presente_special_jury_prize
# Error fetching URL: https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_cineasti_del_presente_emerging_director, 429 Client Error: Too Many Requests for url: https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_cineasti_del_presente_emerging_director
# Error fetching URL: https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_cineasti_del_presente_best_actress, 429 Client Error: Too Many Requests for url: https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_cineasti_del_presente_best_actress
# Error fetching URL: https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_cineasti_del_presente_best_actor, 429 Client Error: Too Many Requests for url: https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_cineasti_del_presente_best_actor
# Error fetching URL: https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_cineasti_del_presente_special_mention, 429 Client Error: Too Many Requests for url: https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_cineasti_del_presente_special_mention
# Error fetching URL: https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_arrangement_prize, 429 Client Error: Too Many Requests for url: https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_arrangement_prize
# Error fetching URL: https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_audience_award, 429 Client Error: Too Many Requests for url: https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_audience_award
# Error fetching URL: https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_variety_award, 429 Client Error: Too Many Requests for url: https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_variety_award
# Error fetching URL: https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_pardo_verde, 429 Client Error: Too Many Requests for url: https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_pardo_verde
# Error fetching URL: https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_pardo_verde_special_mention, 429 Client Error: Too Many Requests for url: https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_pardo_verde_special_mention
# Error fetching URL: https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_pardo_verde_special_mention_short, 429 Client Error: Too Many Requests for url: https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_pardo_verde_special_mention_short
# Error fetching URL: https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_funniest_film_prize, 429 Client Error: Too Many Requests for url: https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_funniest_film_prize
# Error fetching URL: https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_role_of_composition, 429 Client Error: Too Many Requests for url: https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_role_of_composition
# Error fetching URL: https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_best_first_feature, 429 Client Error: Too Many Requests for url: https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_best_first_feature
# Error fetching URL: https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_best_first_feature_mention, 429 Client Error: Too Many Requests for url: https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_best_first_feature_mention
# Error fetching URL: https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_swiss_federation, 429 Client Error: Too Many Requests for url: https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_swiss_federation
# Error fetching URL: https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_fipresci, 429 Client Error: Too Many Requests for url: https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_fipresci
# Error fetching URL: https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_europa_cinemas_label_award, 429 Client Error: Too Many Requests for url: https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_europa_cinemas_label_award
# Error fetching URL: https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_ecumenical_award, 429 Client Error: Too Many Requests for url: https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_ecumenical_award
# Error fetching URL: https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_ecumenical_mention, 429 Client Error: Too Many Requests for url: https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_ecumenical_mention
# Error fetching URL: https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_best_short_film, 429 Client Error: Too Many Requests for url: https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_best_short_film
# Error fetching URL: https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_best_animation_short_film, 429 Client Error: Too Many Requests for url: https://www.filmaffinity.com/en/awards-history.php?cat-id=locarno_best_animation_short_film
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 380
#     376     return all_winners
#     379 # Scrape winners from the URLs
# --> 380 winners = scrape_winners(urls)
#     382 # Write the winners to a CSV file
#     383 with open('all_film_affinity_winners.csv', 'w', newline='', encoding='utf-8') as csvfile:
#
# Cell In[4], line 346, in scrape_winners(urls)
#     343 city, category = get_category_and_city_from_url(url)
#     345 try:
# --> 346     response = requests.get(url)
#     347     response.raise_for_status()
#     348 except requests.exceptions.RequestException as e:
#
# File ~\anaconda3\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~\anaconda3\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~\anaconda3\Lib\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File ~\anaconda3\Lib\site-packages\urllib3\connectionpool.py:714, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     711     self._prepare_proxy(conn)
#     713 # Make the request on the httplib connection object.
# --> 714 httplib_response = self._make_request(
#     715     conn,
#     716     method,
#     717     url,
#     718     timeout=timeout_obj,
#     719     body=body,
#     720     headers=headers,
#     721     chunked=chunked,
#     722 )
#     724 # If we're going to release the connection in ``finally:``, then
#     725 # the response doesn't need to know about the connection. Otherwise
#     726 # it will also try to release it and we'll have a double-release
#     727 # mess.
#     728 response_conn = conn if not release_conn else None
#
# File ~\anaconda3\Lib\site-packages\urllib3\connectionpool.py:466, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     461             httplib_response = conn.getresponse()
#     462         except BaseException as e:
#     463             # Remove the TypeError from the exception chain in
#     464             # Python 3 (including for exceptions like SystemExit).
#     465             # Otherwise it looks like a bug in the code.
# --> 466             six.raise_from(e, None)
#     467 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     468     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~\anaconda3\Lib\site-packages\urllib3\connectionpool.py:461, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     458 except TypeError:
#     459     # Python 3
#     460     try:
# --> 461         httplib_response = conn.getresponse()
#     462     except BaseException as e:
#     463         # Remove the TypeError from the exception chain in
#     464         # Python 3 (including for exceptions like SystemExit).
#     465         # Otherwise it looks like a bug in the code.
#     466         six.raise_from(e, None)
#
# File ~\anaconda3\Lib\http\client.py:1378, in HTTPConnection.getresponse(self)
#    1376 try:
#    1377     try:
# -> 1378         response.begin()
#    1379     except ConnectionError:
#    1380         self.close()
#
# File ~\anaconda3\Lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File ~\anaconda3\Lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File ~\anaconda3\Lib\socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File ~\anaconda3\Lib\ssl.py:1311, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1307     if flags != 0:
#    1308         raise ValueError(
#    1309           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1310           self.__class__)
# -> 1311     return self.read(nbytes, buffer)
#    1312 else:
#    1313     return super().recv_into(buffer, nbytes, flags)
#
# File ~\anaconda3\Lib\ssl.py:1167, in SSLSocket.read(self, len, buffer)
#    1165 try:
#    1166     if buffer is not None:
# -> 1167         return self._sslobj.read(len, buffer)
#    1168     else:
#    1169         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
import requests
from bs4 import BeautifulSoup
import csv
import re

# Define the categories you want to scrape
categories = [
    "choice_award",
    "choice_award_doc",
    "best_canadian_film",
    "best_canadian_film_citation",
    "best_canadian_first_film",
    "best_female_director",
    "choice_award_mad",
    "platform_winner",
    "platform_mention",
    "fipresci",
    "discovery_award",
    "netpac_award",
    "changemaker_award"
]

def remove_text_in_parentheses(text):
    # Remove text within parentheses
    text = re.sub(r'\([^)]*\)', '', text)
    # Remove text within single quotes
    text = re.sub(r"'[^']*'", '', text)
    # Remove text within double quotes
    text = re.sub(r'"[^"]*"', '', text)
    return text.strip()

# Function to scrape the winners of a specific category
def scrape_winners(cat_id):
    url = f"https://www.filmaffinity.com/en/awards-history.php?cat-id=toronto_{cat_id}"
    try:
        response = requests.get(url)
        response.raise_for_status()  # Raise an exception for bad status codes
    except requests.exceptions.RequestException as e:
        print(f"Error fetching URL for category {cat_id}: {e}")
        return []

    soup = BeautifulSoup(response.text, 'html.parser')

    # Find the wrapper with the awards
    wrapper = soup.find('div', {'class': 'wrapper'})

    # Check if the wrapper was found
    if wrapper is None:
        print(f"Error: Couldn't find a wrapper with class 'wrapper' for category {cat_id}")
        return []

    # Find all the list items in the wrapper
    list_items = wrapper.find_all('li', class_=lambda x: x != 'empty-box')

    # Extract the information from each list item
    winners = []
    for item in list_items:
        year_elem = item.find('div', {'class': 'year'})
        movie_title_elem = item.find('span', {'class': 'movie-title-link'})
        director_elem = item.find('div', {'class': 'director'})
        cast_elem = item.find('div', {'class': 'cast'})
        
        if year_elem and movie_title_elem and director_elem and cast_elem:
            year = year_elem.text.strip()
            movie_title = movie_title_elem.text.strip()
            # Remove text within parentheses and quotation marks from the movie title
            movie_title = remove_text_in_parentheses(movie_title)
            director = director_elem.text.strip()
            cast = cast_elem.text.strip()
            winners.append([year, movie_title, director, cast])

    return winners

# Loop through all the categories and scrape the winners
with open('toronto_film_affinity_winners.csv', 'w', newline='', encoding='utf-8') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['Category', 'Year', 'Movie Title', 'Director', 'Cast'])

    for cat_id in categories:
        winners = scrape_winners(cat_id)
        for winner in winners:
            writer.writerow([cat_id.capitalize().replace("_", " "), *winner])

# %%
import requests
from bs4 import BeautifulSoup
import csv
import re

# Define the categories you want to scrape
categories = [
    "golden_lion",
    "mussolini_cup",
    "grand_jury_prize",
    "silver_lion",
    "special_jury_prize",
    "best_actress",
    "best_actor",
    "best_supporting_actress",
    "best_supporting_actor",
    "best_screenplay",
    "best_cinematography",
    "best_technical",
    "new_young_actor",
    "fipresci",
    "orizzonti_best_film",
    "orizzonti_extra_best_film",
    "orizzonti_best_direction",
    "orizzonti_best_screenplay",
    "orizzonti_best_actor",
    "orizzonti_best_actress",
    "audience_award",
    "signis_award",
    "ocic_award",
    "unesco",
    "fedic_award",
    "special_lion",
    "best_first_work",
    "best_ensemble_cast",
    "best_foreign_film",
    "best_italian_film",
    "best_short_film"
]

def remove_text_in_parentheses(text):
    # Remove text within parentheses
    text = re.sub(r'\([^)]*\)', '', text)
    # Remove text within single quotes
    text = re.sub(r"'[^']*'", '', text)
    # Remove text within double quotes
    text = re.sub(r'"[^"]*"', '', text)
    return text.strip()

# Function to scrape the winners of a specific category
def scrape_winners(cat_id):
    url = f"https://www.filmaffinity.com/en/awards-history.php?cat-id=venice_{cat_id}"
    try:
        response = requests.get(url)
        response.raise_for_status()  # Raise an exception for bad status codes
    except requests.exceptions.RequestException as e:
        print(f"Error fetching URL for category {cat_id}: {e}")
        return []

    soup = BeautifulSoup(response.text, 'html.parser')

    # Find the wrapper with the awards
    wrapper = soup.find('div', {'class': 'wrapper'})

    # Check if the wrapper was found
    if wrapper is None:
        print(f"Error: Couldn't find a wrapper with class 'wrapper' for category {cat_id}")
        return []

    # Find all the list items in the wrapper
    list_items = wrapper.find_all('li', class_=lambda x: x != 'empty-box')

    # Extract the information from each list item
    winners = []
    for item in list_items:
        year_elem = item.find('div', {'class': 'year'})
        movie_title_elem = item.find('span', {'class': 'movie-title-link'})
        director_elem = item.find('div', {'class': 'director'})
        cast_elem = item.find('div', {'class': 'cast'})
        
        if year_elem and movie_title_elem and director_elem and cast_elem:
            year = year_elem.text.strip()
            movie_title = movie_title_elem.text.strip()
            # Remove text within parentheses and quotation marks from the movie title
            movie_title = remove_text_in_parentheses(movie_title)
            director = director_elem.text.strip()
            cast = cast_elem.text.strip()
            winners.append([year, movie_title, director, cast])

    return winners

# Loop through all the categories and scrape the winners
with open('venice_film_affinity_winners.csv', 'w', newline='', encoding='utf-8') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['Category', 'Year', 'Movie Title', 'Director', 'Cast'])

    for cat_id in categories:
        winners = scrape_winners(cat_id)
        for winner in winners:
            writer.writerow([cat_id.capitalize().replace("_", " "), *winner])

# %%
import requests
from bs4 import BeautifulSoup
import csv
import re

# Define the categories you want to scrape
categories = [
    "golden_bear",
    "honourable_mention",
    "grand_jury_prize",
    "special_jury_prize",
    "special_prize",
    "best_director",
    "best_leading_performance",
    "best_actress",
    "best_acting_team",
    "best_screenplay",
    "silver_bear",
    "best_actor",
    "jury_prize",
    "outstanding_single_archievement",
    "art_contribution",
    "best_film_music",
    "bronze_bear",
    "best_debut",
    "fipresci",
    "fipresci_prize_honourable",
    "ocic_award",
    "ocic_award_honourable",
    "ocic_award_recommendation",
    "alfred_bauer_prize",
    "blue_angel_award",
    "piper_heidsieck",
    "piper_heidsieck_actress",
    "cicae_award",
    "cidalc_award",
    "interfilm_award",
    "interfilm_otto_award",
    "interfilm_award_recommendation",
    "interfilm_award_honorable",
    "unicrit_award",
    "unicrit_award_honorable",
    "special_mention",
    "big_gold_medal",
    "big_silver_medal",
    "big_bronze_medal",
    "panorama_audience_film"
    "panorama_audience_doc",
    "generation_kplus_grand_prix",
    "generation_kplus_special_prize_short",
    "generation_kplus_crystal_bear",
    "international_best_short_film",
    "short_film_jury_prize",
    "best_documentary",
    "documentary_special_mention"
]

def remove_text_in_parentheses(text):
    # Remove text within parentheses
    text = re.sub(r'\([^)]*\)', '', text)
    # Remove text within single quotes
    text = re.sub(r"'[^']*'", '', text)
    # Remove text within double quotes
    text = re.sub(r'"[^"]*"', '', text)
    return text.strip()

# Function to scrape the winners of a specific category
def scrape_winners(cat_id):
    url = f"https://www.filmaffinity.com/en/awards-history.php?cat-id=berlin_{cat_id}"
    try:
        response = requests.get(url)
        response.raise_for_status()  # Raise an exception for bad status codes
    except requests.exceptions.RequestException as e:
        print(f"Error fetching URL for category {cat_id}: {e}")
        return []

    soup = BeautifulSoup(response.text, 'html.parser')

    # Find the wrapper with the awards
    wrapper = soup.find('div', {'class': 'wrapper'})

    # Check if the wrapper was found
    if wrapper is None:
        print(f"Error: Couldn't find a wrapper with class 'wrapper' for category {cat_id}")
        return []

    # Find all the list items in the wrapper
    list_items = wrapper.find_all('li', class_=lambda x: x != 'empty-box')

    # Extract the information from each list item
    winners = []
    for item in list_items:
        year_elem = item.find('div', {'class': 'year'})
        movie_title_elem = item.find('span', {'class': 'movie-title-link'})
        director_elem = item.find('div', {'class': 'director'})
        cast_elem = item.find('div', {'class': 'cast'})
        
        if year_elem and movie_title_elem and director_elem and cast_elem:
            year = year_elem.text.strip()
            movie_title = movie_title_elem.text.strip()
            # Remove text within parentheses and quotation marks from the movie title
            movie_title = remove_text_in_parentheses(movie_title)
            director = director_elem.text.strip()
            cast = cast_elem.text.strip()
            winners.append([year, movie_title, director, cast])

    return winners

# Loop through all the categories and scrape the winners
with open('berlin_film_affinity_winners.csv', 'w', newline='', encoding='utf-8') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['Category', 'Year', 'Movie Title', 'Director', 'Cast'])

    for cat_id in categories:
        winners = scrape_winners(cat_id)
        for winner in winners:
            writer.writerow([cat_id.capitalize().replace("_", " "), *winner])

# %%
import requests
from bs4 import BeautifulSoup
import csv
import re

# Define the categories you want to scrape
categories = [
    "best_feature",
    "special_distinction",
    "best_film_contrechamp",
    "audience_award",
    "cristal_best_short_film",
    "special_jury_award",
    "best_first_film",
    "special_distinction_short_film"
    "best_music",
    "audience_award_short_film",
    "fipresci",
    "junior_jury_award_short_film",
    "off-limits_award",
    "best_tv_production",
    "best_graduation_film",
    "best_commissioned_film",
    "city_of_annecy_award",
    "paul_grimault_award",
    "gan_foundation"
]

def remove_text_in_parentheses(text):
    # Remove text within parentheses
    text = re.sub(r'\([^)]*\)', '', text)
    # Remove text within single quotes
    text = re.sub(r"'[^']*'", '', text)
    # Remove text within double quotes
    text = re.sub(r'"[^"]*"', '', text)
    return text.strip()

# Function to scrape the winners of a specific category
def scrape_winners(cat_id):
    url = f"https://www.filmaffinity.com/en/awards-history.php?cat-id=annecy_{cat_id}"
    try:
        response = requests.get(url)
        response.raise_for_status()  # Raise an exception for bad status codes
    except requests.exceptions.RequestException as e:
        print(f"Error fetching URL for category {cat_id}: {e}")
        return []

    soup = BeautifulSoup(response.text, 'html.parser')

    # Find the wrapper with the awards
    wrapper = soup.find('div', {'class': 'wrapper'})

    # Check if the wrapper was found
    if wrapper is None:
        print(f"Error: Couldn't find a wrapper with class 'wrapper' for category {cat_id}")
        return []

    # Find all the list items in the wrapper
    list_items = wrapper.find_all('li', class_=lambda x: x != 'empty-box')

    # Extract the information from each list item
     winners = []
    for item in list_items:
        year_elem = item.find('div', {'class': 'year'})
        movie_title_elem = item.find('span', {'class': 'movie-title-link'})
        director_elem = item.find('div', {'class': 'director'})
        cast_elem = item.find('div', {'class': 'cast'})
        
        if year_elem and movie_title_elem and director_elem and cast_elem:
            year = year_elem.text.strip()
            movie_title = movie_title_elem.text.strip()
            # Remove text within parentheses and quotation marks from the movie title
            movie_title = remove_text_in_parentheses(movie_title)
            director = director_elem.text.strip()
            cast = cast_elem.text.strip()
            winners.append([year, movie_title, director, cast])

    return winners

# Loop through all the categories and scrape the winners
with open('annecy_film_affinity_winners.csv', 'w', newline='', encoding='utf-8') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['Category', 'Year', 'Movie Title', 'Director', 'Cast'])

    for cat_id in categories:
        winners = scrape_winners(cat_id)
        for winner in winners:
            writer.writerow([cat_id.capitalize().replace("_", " "), *winner])

# %%
import requests
from bs4 import BeautifulSoup
import csv
import re

# Define the categories you want to scrape
categories = [
    "best_picture",
    "special_jury_award",
    "best_director",
    "best_actor",
    "best_actress",
    "best_screenplay",
    "new_director",
    "best_cinematography",
    "best_production_design",
    "best_special_effects",
    "best_make_up_fx",
    "best_ost",
    "special_mention",
    "audience_award",
    "fipresci",
    "best_european_film",
    "best_film_panorama",
    "best_animated_feature",
    "best_animated_kids",
    "best_short_film_animated",
    "best_short_film",
    "best_new_director",
    "best_film_focus_asia",
    "best_film_novesvisions",
    "best_film_novesvisions_one",
    "best_director_novesvisions",
    "special_mention_noves_visions",
    "best_short_film_novesvisions",
    "best_film_novesvisions_plus",
    "best_film_midnight",
    "best_film_orbita",
    "serial_sitges",
    "best_film_silver_melies",
    "best_film_blood_window",
    "best_short_film_silver_melies",
    "best_short_film_brigadoon",
    "sgae_nova_autoria_best_direction",
    "sgae_nova_autoria_best_screenplay",
    "sgae_nova_autoria_best_music",
    "best_film_jove_juryaward"
]

def remove_text_in_parentheses(text):
    # Remove text within parentheses
    text = re.sub(r'\([^)]*\)', '', text)
    # Remove text within single quotes
    text = re.sub(r"'[^']*'", '', text)
    # Remove text within double quotes
    text = re.sub(r'"[^"]*"', '', text)
    return text.strip()

# Function to scrape the winners of a specific category
def scrape_winners(cat_id):
    url = f"https://www.filmaffinity.com/en/awards-history.php?cat-id=sitges_{cat_id}"
    try:
        response = requests.get(url)
        response.raise_for_status()  # Raise an exception for bad status codes
    except requests.exceptions.RequestException as e:
        print(f"Error fetching URL for category {cat_id}: {e}")
        return []

    soup = BeautifulSoup(response.text, 'html.parser')

    # Find the wrapper with the awards
    wrapper = soup.find('div', {'class': 'wrapper'})

    # Check if the wrapper was found
    if wrapper is None:
        print(f"Error: Couldn't find a wrapper with class 'wrapper' for category {cat_id}")
        return []

    # Find all the list items in the wrapper
    list_items = wrapper.find_all('li', class_=lambda x: x != 'empty-box')

    # Extract the information from each list item
    winners = []
    for item in list_items:
        year_elem = item.find('div', {'class': 'year'})
        movie_title_elem = item.find('span', {'class': 'movie-title-link'})
        director_elem = item.find('div', {'class': 'director'})
        cast_elem = item.find('div', {'class': 'cast'})
        
        if year_elem and movie_title_elem and director_elem and cast_elem:
            year = year_elem.text.strip()
            movie_title = movie_title_elem.text.strip()
            # Remove text within parentheses and quotation marks from the movie title
            movie_title = remove_text_in_parentheses(movie_title)
            director = director_elem.text.strip()
            cast = cast_elem.text.strip()
            winners.append([year, movie_title, director, cast])

    return winners

# Loop through all the categories and scrape the winners
with open('sitges_film_affinity_winners.csv', 'w', newline='', encoding='utf-8') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['Category', 'Year', 'Movie Title', 'Director', 'Cast'])

    for cat_id in categories:
        winners = scrape_winners(cat_id)
        for winner in winners:
            writer.writerow([cat_id.capitalize().replace("_", " "), *winner])

# %%
import requests
from bs4 import BeautifulSoup
import csv
import re

# Define the categories you want to scrape
categories = [
    "best_feature",
    "special_jury_prize",
    "best_director",
    "best_screenplay",
    "best_actor",
    "best_actress",
    "audience_award",
    "best_artistic_contribution"
]

def remove_text_in_parentheses(text):
    # Remove text within parentheses
    text = re.sub(r'\([^)]*\)', '', text)
    # Remove text within single quotes
    text = re.sub(r"'[^']*'", '', text)
    # Remove text within double quotes
    text = re.sub(r'"[^"]*"', '', text)
    return text.strip()

# Function to scrape the winners of a specific category
def scrape_winners(cat_id):
    url = f"https://www.filmaffinity.com/en/awards-history.php?cat-id=kyoto_{cat_id}"
    try:
        response = requests.get(url)
        response.raise_for_status()  # Raise an exception for bad status codes
    except requests.exceptions.RequestException as e:
        print(f"Error fetching URL for category {cat_id}: {e}")
        return []

    soup = BeautifulSoup(response.text, 'html.parser')

    # Find the wrapper with the awards
    wrapper = soup.find('div', {'class': 'wrapper'})

    # Check if the wrapper was found
    if wrapper is None:
        print(f"Error: Couldn't find a wrapper with class 'wrapper' for category {cat_id}")
        return []

    # Find all the list items in the wrapper
    list_items = wrapper.find_all('li', class_=lambda x: x != 'empty-box')

    # Extract the information from each list item
    winners = []
    for item in list_items:
        year_elem = item.find('div', {'class': 'year'})
        movie_title_elem = item.find('span', {'class': 'movie-title-link'})
        director_elem = item.find('div', {'class': 'director'})
        cast_elem = item.find('div', {'class': 'cast'})
        
        if year_elem and movie_title_elem and director_elem and cast_elem:
            year = year_elem.text.strip()
            movie_title = movie_title_elem.text.strip()
            # Remove text within parentheses and quotation marks from the movie title
            movie_title = remove_text_in_parentheses(movie_title)
            director = director_elem.text.strip()
            cast = cast_elem.text.strip()
            winners.append([year, movie_title, director, cast])

    return winners

# Loop through all the categories and scrape the winners
with open('tokyo_film_affinity_winners.csv', 'w', newline='', encoding='utf-8') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['Category', 'Year', 'Movie Title', 'Director', 'Cast'])

    for cat_id in categories:
        winners = scrape_winners(cat_id)
        for winner in winners:
            writer.writerow([cat_id.capitalize().replace("_", " "), *winner])

# %%
import requests
from bs4 import BeautifulSoup
import csv
import re


# Define the categories you want to scrape
categories = [
    "best_film",
    "special_jury_award",
    "special_mention",
    "best_director",
    "best_performance",
    "best_actor",
    "best_actress",
    "best_screenplay",
    "best_iberoamerican",
    "iberoamerican_mention",
    "special_jury_mention",
    "iberoamerican_special_jury_award",
    "best_argentinian_film",
    "best_argentinian_director",
    "argentinian_mention",
    "fipresci",
    "audience_award",
    "best_short_film",
    "best_argentinian_short_film"
]

def remove_text_in_parentheses(text):
    # Remove text within parentheses
    text = re.sub(r'\([^)]*\)', '', text)
    # Remove text within single quotes
    text = re.sub(r"'[^']*'", '', text)
    # Remove text within double quotes
    text = re.sub(r'"[^"]*"', '', text)
    return text.strip()

# Function to scrape the winners of a specific category
def scrape_winners(cat_id):
    url = f"https://www.filmaffinity.com/en/awards-history.php?cat-id=mar_{cat_id}"
    try:
        response = requests.get(url)
        response.raise_for_status()  # Raise an exception for bad status codes
    except requests.exceptions.RequestException as e:
        print(f"Error fetching URL for category {cat_id}: {e}")
        return []

    soup = BeautifulSoup(response.text, 'html.parser')

    # Find the wrapper with the awards
    wrapper = soup.find('div', {'class': 'wrapper'})

    # Check if the wrapper was found
    if wrapper is None:
        print(f"Error: Couldn't find a wrapper with class 'wrapper' for category {cat_id}")
        return []

    # Find all the list items in the wrapper
    list_items = wrapper.find_all('li', class_=lambda x: x != 'empty-box')

    # Extract the information from each list item
    winners = []
    for item in list_items:
        year_elem = item.find('div', {'class': 'year'})
        movie_title_elem = item.find('span', {'class': 'movie-title-link'})
        director_elem = item.find('div', {'class': 'director'})
        cast_elem = item.find('div', {'class': 'cast'})
        
        if year_elem and movie_title_elem and director_elem and cast_elem:
            year = year_elem.text.strip()
            movie_title = movie_title_elem.text.strip()
            # Remove text within parentheses and quotation marks from the movie title
            movie_title = remove_text_in_parentheses(movie_title)
            director = director_elem.text.strip()
            cast = cast_elem.text.strip()
            winners.append([year, movie_title, director, cast])

    return winners

# Loop through all the categories and scrape the winners
with open('mar_film_affinity_winners.csv', 'w', newline='', encoding='utf-8') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['Category', 'Year', 'Movie Title', 'Director', 'Cast'])

    for cat_id in categories:
        winners = scrape_winners(cat_id)
        for winner in winners:
            writer.writerow([cat_id.capitalize().replace("_", " "), *winner])

# %%
import requests
from bs4 import BeautifulSoup
import csv
import re


# Define the categories you want to scrape
categories = [
    "best_film",
    "second_best_film",
    "jury_grand_prix",
    "special_jury_award",
    "jury_prix",
    "best_director",
    "best_actor",
    "best_actress",
    "best_screenplay",
    "best_cinematography",
    "best_music",
    "best_technology",
    "artistic_achievement",
    "best_animated_film",
    "best_documentary",
    "best_short_film",
    "best_animated_short_film"
]

def remove_text_in_parentheses(text):
    # Remove text within parentheses
    text = re.sub(r'\([^)]*\)', '', text)
    # Remove text within single quotes
    text = re.sub(r"'[^']*'", '', text)
    # Remove text within double quotes
    text = re.sub(r'"[^"]*"', '', text)
    return text.strip()

# Function to scrape the winners of a specific category
def scrape_winners(cat_id):
    url = f"https://www.filmaffinity.com/en/awards-history.php?cat-id=shanghai_{cat_id}"
    try:
        response = requests.get(url)
        response.raise_for_status()  # Raise an exception for bad status codes
    except requests.exceptions.RequestException as e:
        print(f"Error fetching URL for category {cat_id}: {e}")
        return []

    soup = BeautifulSoup(response.text, 'html.parser')

    # Find the wrapper with the awards
    wrapper = soup.find('div', {'class': 'wrapper'})

    # Check if the wrapper was found
    if wrapper is None:
        print(f"Error: Couldn't find a wrapper with class 'wrapper' for category {cat_id}")
        return []

    # Find all the list items in the wrapper
    list_items = wrapper.find_all('li', class_=lambda x: x != 'empty-box')

    # Extract the information from each list item
    winners = []
    for item in list_items:
        year_elem = item.find('div', {'class': 'year'})
        movie_title_elem = item.find('span', {'class': 'movie-title-link'})
        director_elem = item.find('div', {'class': 'director'})
        cast_elem = item.find('div', {'class': 'cast'})
        
        if year_elem and movie_title_elem and director_elem and cast_elem:
            year = year_elem.text.strip()
            movie_title = movie_title_elem.text.strip()
            # Remove text within parentheses and quotation marks from the movie title
            movie_title = remove_text_in_parentheses(movie_title)
            director = director_elem.text.strip()
            cast = cast_elem.text.strip()
            winners.append([year, movie_title, director, cast])

    return winners

# Loop through all the categories and scrape the winners
with open('shanghai_film_affinity_winners.csv', 'w', newline='', encoding='utf-8') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['Category', 'Year', 'Movie Title', 'Director', 'Cast'])

    for cat_id in categories:
        winners = scrape_winners(cat_id)
        for winner in winners:
            writer.writerow([cat_id.capitalize().replace("_", " "), *winner])

# %%
file_path = "C:/Users/frivo/Downloads/title.akas.tsv/title.akas.tsv"

# Open the file in read mode
with open(file_path, 'r', encoding='utf-8') as file:
    # Iterate over the first 10 lines in the file
    for line_number, line in enumerate(file):
        if line_number >= 10:
            break
        # Print each line
        print(line.strip())
# Out:
# titleId	ordering	title	region	language	types	attributes	isOriginalTitle
# tt0000001	1	Carmencita	\N	\N	original	\N	1
# tt0000001	2	Carmencita	DE	\N	\N	literal title	0
# tt0000001	3	Carmencita	US	\N	imdbDisplay	\N	0
# tt0000001	4	Carmencita - spanyol tánc	HU	\N	imdbDisplay	\N	0
# tt0000001	5	Καρμενσίτα	GR	\N	imdbDisplay	\N	0
# tt0000001	6	Карменсита	RU	\N	imdbDisplay	\N	0
# tt0000001	7	Карменсіта	UA	\N	imdbDisplay	\N	0
# tt0000001	8	カルメンチータ	JP	ja	imdbDisplay	\N	0
# tt0000002	1	Le clown et ses chiens	\N	\N	original	\N	1

# %%
import pandas as pd

# List of CSV file paths
csv_files = [
    "C:/Users/frivo/Documents/csv coding project/annecy_film_affinity_winners.csv",
    "C:/Users/frivo/Documents/csv coding project/berlin_film_affinity_winners.csv",
    "C:/Users/frivo/Documents/csv coding project/cannes_film_affinity_winners.csv",
    "C:/Users/frivo/Documents/csv coding project/mar_film_affinity_winners.csv",
    "C:/Users/frivo/Documents/csv coding project/shanghai_film_affinity_winners.csv",
    "C:/Users/frivo/Documents/csv coding project/stiges_film_affinity_winners.csv",
    "C:/Users/frivo/Documents/csv coding project/tokyo_film_affinity_winners.csv",
    "C:/Users/frivo/Documents/csv coding project/toronto_film_affinity_winners.csv",
    "C:/Users/frivo/Documents/csv coding project/venice_film_affinity_winners.csv"
]

# TSV file path
tsv_file = "C:/Users/frivo/Downloads/title.akas.tsv/title.akas.tsv"

# Load TSV file
tsv_df = pd.read_csv(tsv_file, sep='\t')

# List to store lines from TSV file
tsv_lines = []

# Iterate over each CSV file
for csv_file in csv_files:
    # Load CSV file
    csv_df = pd.read_csv(csv_file)
    
    # Ensure column name consistency
    if 'Movie Title' in csv_df.columns:
        csv_df.rename(columns={'Movie Title': 'title'}, inplace=True)

    # Extract movie titles
    movie_titles = csv_df['title'].tolist()

    # Search for movie titles in TSV file
    for title in movie_titles:
        found_lines = tsv_df[tsv_df['title'] == title]
        if not found_lines.empty:
            tsv_lines.extend(found_lines.values.tolist())

# Create DataFrame from found lines
result_df = pd.DataFrame(tsv_lines, columns=tsv_df.columns)

# Write result to CSV file
result_df.to_csv('result.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 39
#      37 # Search for movie titles in TSV file
#      38 for title in movie_titles:
# ---> 39     found_lines = tsv_df[tsv_df['title'] == title]
#      40     if not found_lines.empty:
#      41         tsv_lines.extend(found_lines.values.tolist())
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3752, in DataFrame.__getitem__(self, key)
#    3750 # Do we have a (boolean) 1d indexer?
#    3751 if com.is_bool_indexer(key):
# -> 3752     return self._getitem_bool_array(key)
#    3754 # We are left with two options: a single key, and a collection of keys,
#    3755 # We interpret tuples as collections only for non-MultiIndex
#    3756 is_single_key = isinstance(key, tuple) or not is_list_like(key)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3807, in DataFrame._getitem_bool_array(self, key)
#    3803 # check_bool_indexer will throw exception if Series key cannot
#    3804 # be reindexed to match DataFrame rows
#    3805 key = check_bool_indexer(self.index, key)
# -> 3807 if key.all():
#    3808     return self.copy(deep=None)
#    3810 indexer = key.nonzero()[0]
#
# File ~\anaconda3\Lib\site-packages\numpy\core\_methods.py:64, in _all(a, axis, dtype, out, keepdims, where)
#      61 def _all(a, axis=None, dtype=None, out=None, keepdims=False, *, where=True):
#      62     # Parsing keyword arguments is currently fairly slow, so avoid it for now
#      63     if where is True:
# ---> 64         return umr_all(a, axis, dtype, out, keepdims)
#      65     return umr_all(a, axis, dtype, out, keepdims, where=where)
#
# KeyboardInterrupt:

# %%
import pandas as pd
import re

# CSV file path
csv_file = "C:/Users/frivo/Documents/csv coding project/annecy_film_affinity_winners.csv"

# TSV file path
tsv_file_path = "C:/Users/frivo/Downloads/title.akas.tsv/title.akas.tsv"

# Read all lines from the CSV file starting from the second line
with open(csv_file, 'r', encoding='utf-8') as file:
    csv_lines = file.readlines()[1:]

# Preprocess TSV file into a dictionary for faster lookups
tsv_lookup = {}
with open(tsv_file_path, 'r', encoding='utf-8') as tsv_file:
    for line in tsv_file:
        # Extract title from the TSV line
        movie_title_tsv = line.split('\t')[2].strip()  # Assuming the title is the third column
        
        # Remove spaces and special characters from the TSV title
        movie_title_tsv = re.sub(r'\W+', '', movie_title_tsv)
        
        # Remove (S) from the title if present
        movie_title_tsv = movie_title_tsv.replace('(S)', '')

        # Store line in the dictionary
        tsv_lookup[movie_title_tsv] = line.strip()

# List to store found lines
found_lines = []

# List to store line numbers not found in TSV file
lines_not_found = []

# Search for each line from the CSV file in the TSV dictionary
for line_num, csv_line in enumerate(csv_lines, start=2):  # Start from line 2
    if line_num % 10 == 0:  # Print line number every 10 lines
        print(f"Processing line {line_num}...")

    # Extract movie title from the CSV line
    movie_title_csv = csv_line.strip().split(',')[2].strip()

    # Remove spaces and special characters from movie title
    movie_title_csv = re.sub(r'\W+', '', movie_title_csv)
    
    # Remove (S) from the title if present
    movie_title_csv = movie_title_csv.replace('(S)', '')

    # Search for the movie title in the TSV dictionary
    tsv_line = tsv_lookup.get(movie_title_csv)
    if tsv_line:
        found_lines.append(tsv_line)
    else:
        lines_not_found.append((line_num, csv_line.strip()))
        print(f"Line {line_num}: '{csv_line.strip()}' not found in TSV file.")

# Write found lines to a CSV file
found_df = pd.DataFrame(found_lines, columns=['TSV Line'])
found_df.to_csv('found_lines_annecy.csv', index=False)

print("Total lines not found in TSV file:", len(lines_not_found))
print("Lines not found in TSV file:")
for line_num, line_content in lines_not_found:
    print(f"Line {line_num}: {line_content}")
# Out:
# Processing line 10...
# Processing line 20...
# Line 23: 'Best feature,2002,"My Beautiful Girl, Mari",Lee Seong-Kang,Animation' not found in TSV file.
# Processing line 30...
# Line 39: 'Special distinction,2013,"Ma maman est en Amérique, elle a rencontré Buffalo Bill","Marc Boreal, Thibaut Chatel","Animation,  Voice: Marc Lavoine, Julie Depardieu"' not found in TSV file.
# Processing line 40...
# Line 42: 'Special distinction,2010,Eleonore's Secret,Dominique Monfery,"Animation,  Voice: Jeanne Moreau, Julie Gayet ..."' not found in TSV file.
# Processing line 50...
# Processing line 60...
# Line 64: 'Special jury award,2023,Scavengers Reign  Second Jury Award for a TV Series,"Joseph Bennett (Creator), Charles Huettner (Creator) ...","Animation,  Voice: Sunita Mani, Wunmi Mosaku ..."' not found in TSV file.
# Line 67: 'Special jury award,2020,The Nose or the Conspiracy of Mavericks,Andrei Khrzhanovsky,Animation' not found in TSV file.
# Processing line 70...
# Processing line 80...
# Processing line 90...
# Processing line 100...
# Line 102: 'Audience award short film,2007,Peter & The Wolf,Suzie Templeton,Animation' not found in TSV file.
# Processing line 110...
# Processing line 120...
# Line 123: 'Off-limits award,2023,Is Heaven Blue? #2 ,"Menno de Nooijer, Paul de Nooijer",Animation' not found in TSV file.
# Processing line 130...
# Line 133: 'Best tv production,2019,Panique au village: La Foire agricole ,"Stéphane Aubier, Vincent Patar",Animation' not found in TSV file.
# Processing line 140...
# Line 142: 'Best tv production,2006,Pocoyo and Friends ,"David Cantolla (Creator), Luis Gallego (Creator), Guillermo García Carsi (Creator)",Animation' not found in TSV file.
# Line 149: 'Best graduation film,2017,Summer's Puke is Winter's Delight  Jury Award,Sawako Kabuki,Animation' not found in TSV file.
# Processing line 150...
# Line 158: 'Best commissioned film,2023,November Ultra: Come Into My Arms ,Tamerlan Bekmurzayev,Animation' not found in TSV file.
# Processing line 160...
# Line 162: 'Paul grimault award,2023,"The Tunnel to Summer, the Exit of Goodbyes",Tomohisa Taguchi,Animation' not found in TSV file.
# Total lines not found in TSV file: 12
# Lines not found in TSV file:
# Line 23: Best feature,2002,"My Beautiful Girl, Mari",Lee Seong-Kang,Animation
# Line 39: Special distinction,2013,"Ma maman est en Amérique, elle a rencontré Buffalo Bill","Marc Boreal, Thibaut Chatel","Animation,  Voice: Marc Lavoine, Julie Depardieu"
# Line 42: Special distinction,2010,Eleonore's Secret,Dominique Monfery,"Animation,  Voice: Jeanne Moreau, Julie Gayet ..."
# Line 64: Special jury award,2023,Scavengers Reign  Second Jury Award for a TV Series,"Joseph Bennett (Creator), Charles Huettner (Creator) ...","Animation,  Voice: Sunita Mani, Wunmi Mosaku ..."
# Line 67: Special jury award,2020,The Nose or the Conspiracy of Mavericks,Andrei Khrzhanovsky,Animation
# Line 102: Audience award short film,2007,Peter & The Wolf,Suzie Templeton,Animation
# Line 123: Off-limits award,2023,Is Heaven Blue? #2 ,"Menno de Nooijer, Paul de Nooijer",Animation
# Line 133: Best tv production,2019,Panique au village: La Foire agricole ,"Stéphane Aubier, Vincent Patar",Animation
# Line 142: Best tv production,2006,Pocoyo and Friends ,"David Cantolla (Creator), Luis Gallego (Creator), Guillermo García Carsi (Creator)",Animation
# Line 149: Best graduation film,2017,Summer's Puke is Winter's Delight  Jury Award,Sawako Kabuki,Animation
# Line 158: Best commissioned film,2023,November Ultra: Come Into My Arms ,Tamerlan Bekmurzayev,Animation
# Line 162: Paul grimault award,2023,"The Tunnel to Summer, the Exit of Goodbyes",Tomohisa Taguchi,Animation

# %%
import pandas as pd

# CSV file path
csv_file = "C:/Users/frivo/Documents/csv coding project/berlin_film_affinity_winners.csv"

# TSV file path
tsv_file_path = "C:/Users/frivo/Downloads/title.akas.tsv/title.akas.tsv"

# Read all lines from the CSV file starting from the second line
with open(csv_file, 'r', encoding='utf-8') as file:
    csv_lines = file.readlines()[1:]

# Preprocess TSV file into a dictionary for faster lookups
tsv_lookup = {}
with open(tsv_file_path, 'r', encoding='utf-8') as tsv_file:
    for line in tsv_file:
        # Extract title from the TSV line
        movie_title_tsv = line.split('\t')[2].strip()  # Assuming the title is the third column

        # Remove spaces from the TSV title
        movie_title_tsv = movie_title_tsv.replace(' ', '')
        
        # Store line in the dictionary
        tsv_lookup[movie_title_tsv] = line.strip()

# List to store found lines
found_lines = []

# List to store line numbers not found in TSV file
lines_not_found = []

# Search for each line from the CSV file in the TSV dictionary
for line_num, csv_line in enumerate(csv_lines, start=2):  # Start from line 2
    if line_num % 10 == 0:  # Print line number every 10 lines
        print(f"Processing line {line_num}...")

    # Extract movie title from the CSV line
    movie_title_csv = csv_line.strip().split(',')[2].strip()

    # Remove spaces from movie title
    movie_title_csv = movie_title_csv.replace(' ', '')

    # Search for the movie title in the TSV dictionary
    tsv_line = tsv_lookup.get(movie_title_csv)
    if tsv_line:
        found_lines.append(tsv_line)
    else:
        lines_not_found.append((line_num, csv_line.strip()))
        print(f"Line {line_num}: '{csv_line.strip()}' not found in TSV file.")

# Write found lines to a CSV file
found_df = pd.DataFrame(found_lines, columns=['TSV Line'])
found_df.to_csv('found_lines_berlin.csv', index=False)

print("Total lines not found in TSV file:", len(lines_not_found))
print("Lines not found in TSV file:")
for line_num, line_content in lines_not_found:
    print(f"Line {line_num}: {line_content}")
# Out:
# Processing line 10...
# Line 12: 'Golden bear,2014,"Black Coal, Thin Ice",Diao Yinan,"Liao Fan, Gwei Lun-Mei, Wang Xuebing ..."' not found in TSV file.
# Processing line 20...
# Line 21: 'Golden bear,2005,U-Carmen e-Khayelitsha,Mark Dornford-May,"Pauline Malefane, Andile Tshoni, Zweilungile Sidloyi ..."' not found in TSV file.
# Processing line 30...
# Line 39: 'Golden bear,1987,The Teme,Gleb Panfilov,"Mikhail Ulyanov, Inna Churikova, Stanislav Lyubshin ..."' not found in TSV file.
# Processing line 40...
# Line 45: 'Golden bear,1981,"Fast, Fast",Carlos Saura,"Berta Socuéllamos, José Antonio Valdelomar, Jesús Arias ..."' not found in TSV file.
# Processing line 50...
# Line 50: 'Golden bear,1976,"Buffalo Bill and the Indians, or Sitting Bull's History Lesson",Robert Altman,"Paul Newman, Burt Lancaster, Geraldine Chaplin ..."' not found in TSV file.
# Processing line 60...
# Processing line 70...
# Processing line 80...
# Line 83: 'Honourable mention,1991,Li Lianying: The Imperial Eunuch,Tian Zhuangzhuang,"Jiang Wen, Liu Xiaoqing, Xu Fan ..."' not found in TSV file.
# Processing line 90...
# Line 95: 'Special prize,1967,"Next Year, Same Time",Ulrich Schamoni,"Ulla Jacobsson, Sabine Sinjen, Hans-Dieter Schwarze ..."' not found in TSV file.
# Processing line 100...
# Line 104: 'Special prize,1958,"Two Eyes, Twelve Hands",Rajaram Vankudre Shantaram,"Rajaram Vankudre Shantaram, Sandhya, Ulhas ..."' not found in TSV file.
# Processing line 110...
# Line 111: 'Best director,2019,"I Was at Home, But",Angela Schanelec,"Maren Eggert, Jakob Lassalle, Clara Möller ..."' not found in TSV file.
# Processing line 120...
# Line 124: 'Best director,2006,The Road To Guantanamo,"Michael Winterbottom, Mat Whitecross","Riz Ahmed, Farhad Harun, Waqar Siddiqui ..."' not found in TSV file.
# Processing line 130...
# Processing line 140...
# Line 141: 'Best director,1989,"I Love, You Love",Dusan Hanák,"Roman Klosowski, Iva Janzurová, Milan Jelic"' not found in TSV file.
# Processing line 150...
# Line 156: 'Best director,1968,Peppermint Frappe,Carlos Saura,"Geraldine Chaplin, José Luis López Vázquez, Alfredo Mayo ..."' not found in TSV file.
# Processing line 160...
# Processing line 170...
# Line 170: 'Best leading performance,2023,"20,000 Species of Bees",Estibaliz Urresola Solaguren,"Sofía Otero, Patricia López Arnaiz, Ane Gabaraín ..."' not found in TSV file.
# Line 174: 'Best actress,2019,"So Long, My Son",Wang Xiaoshuai,"Ai Liya, Du Jiang, Zhao Yanguozhang ..."' not found in TSV file.
# Processing line 180...
# Processing line 190...
# Line 193: 'Best actress,2000,The Legends of Rita,Volker Schlöndorff,"Bibiana Beglau, Martin Wuttke, Nadja Uhl ..."' not found in TSV file.
# Line 199: 'Best actress,1994,"Ladybird, Ladybird",Ken Loach,"Crissy Rock, Vladimir Vega, Ray Winstone ..."' not found in TSV file.
# Processing line 200...
# Processing line 210...
# Processing line 220...
# Processing line 230...
# Processing line 240...
# Processing line 250...
# Processing line 260...
# Line 263: 'Silver bear,1954,"Bread, Love and Dreams",Luigi Comencini,"Vittorio De Sica, Gina Lollobrigida, Roberto Risso ..."' not found in TSV file.
# Line 267: 'Best actor,2019,"So Long, My Son",Wang Xiaoshuai,"Ai Liya, Du Jiang, Zhao Yanguozhang ..."' not found in TSV file.
# Processing line 270...
# Line 272: 'Best actor,2014,"Black Coal, Thin Ice",Diao Yinan,"Liao Fan, Gwei Lun-Mei, Wang Xuebing ..."' not found in TSV file.
# Processing line 280...
# Processing line 290...
# Processing line 300...
# Line 306: 'Best actor,1980,The Orchestra Conductor,Andrzej Wajda,"John Gielgud, Krystyna Janda, Andrzej Seweryn ..."' not found in TSV file.
# Processing line 310...
# Processing line 320...
# Line 320: 'Best actor,1962,Mr. Hobbs Takes A Vacation,Henry Koster,"James Stewart, Maureen O'Hara, Lauri Peters ..."' not found in TSV file.
# Processing line 330...
# Processing line 340...
# Processing line 350...
# Processing line 360...
# Line 364: 'Art contribution,2017,"Ana, My Love",Calin Peter Netzer,"Mircea Postelnicu, Diana Cavallioti, Carmen Tanase ..."' not found in TSV file.
# Processing line 370...
# Processing line 380...
# Line 388: 'Art contribution,1988,Verónico Cruz,Miguel Pereira,"Juan José Camero, Gonzalo Morales, René Olaguivel ..."' not found in TSV file.
# Processing line 390...
# Line 394: 'Art contribution,1956,"The Blonde Witch, The Sorceress",André Michel,"Marina Vlady, Maurice Ronet, Nicole Courcel ..."' not found in TSV file.
# Processing line 400...
# Line 404: 'Bronze bear,1952,"Cry, the Beloved Country",Zoltan Korda,"Canada Lee, Charles Carson, Sidney Poitier ..."' not found in TSV file.
# Processing line 410...
# Processing line 420...
# Processing line 430...
# Processing line 440...
# Line 448: 'Fipresci,1987,The Teme,Gleb Panfilov,"Mikhail Ulyanov, Inna Churikova, Stanislav Lyubshin ..."' not found in TSV file.
# Processing line 450...
# Processing line 460...
# Line 462: 'Fipresci,1967,"Next Year, Same Time",Ulrich Schamoni,"Ulla Jacobsson, Sabine Sinjen, Hans-Dieter Schwarze ..."' not found in TSV file.
# Processing line 470...
# Line 472: 'Fipresci prize honourable,1989,"I Love, You Love",Dusan Hanák,"Roman Klosowski, Iva Janzurová, Milan Jelic"' not found in TSV file.
# Processing line 480...
# Processing line 490...
# Processing line 500...
# Line 509: 'Ocic award,1958,"Two Eyes, Twelve Hands",Rajaram Vankudre Shantaram,"Rajaram Vankudre Shantaram, Sandhya, Ulhas ..."' not found in TSV file.
# Processing line 510...
# Line 513: 'Ocic award honourable,1988,Verónico Cruz,Miguel Pereira,"Juan José Camero, Gonzalo Morales, René Olaguivel ..."' not found in TSV file.
# Line 519: 'Ocic award recommendation,1983,"Pra Frente, Brasil",Roberto Farias,"Reginaldo Faria, Carlos Zara, Antonio Fagundes ..."' not found in TSV file.
# Processing line 520...
# Line 522: 'Ocic award recommendation,1977,"The Devil, Probably",Robert Bresson,"Antoine Monnier, Nicolas Deguy, Tina Irissari ..."' not found in TSV file.
# Processing line 530...
# Line 536: 'Alfred bauer prize,2011,"If Not Us, Who",Andres Veiel,"August Diehl, Lena Lauzemis, Susanne Lothar ..."' not found in TSV file.
# Line 537: 'Alfred bauer prize,2010,"If I Want to Whistle, I Whistle",Florin Serban,"George Pistereanu, Ada Condeescu, Mihai Constantin ..."' not found in TSV file.
# Processing line 540...
# Line 540: 'Alfred bauer prize,2007,Is OK,Park Chan-wook,"Lim Soo-jung, Rain, Choi Hee-jin ..."' not found in TSV file.
# Line 543: 'Alfred bauer prize,2004,Maria Full Of Grace,Joshua Marston,"Catalina Sandino Moreno, Yenny Paola Vega, Guilied López ..."' not found in TSV file.
# Processing line 550...
# Line 559: 'Blue angel award,2003,"Good Bye, Lenin!",Wolfgang Becker,"Daniel Brühl, Katrin Saß, Chulpan Khamatova ..."' not found in TSV file.
# Processing line 560...
# Line 562: 'Blue angel award,2000,The Legends of Rita,Volker Schlöndorff,"Bibiana Beglau, Martin Wuttke, Nadja Uhl ..."' not found in TSV file.
# Processing line 570...
# Line 575: 'Cicae award,1987,The Teme,Gleb Panfilov,"Mikhail Ulyanov, Inna Churikova, Stanislav Lyubshin ..."' not found in TSV file.
# Processing line 580...
# Line 582: 'Cidalc award,1987,The Teme,Gleb Panfilov,"Mikhail Ulyanov, Inna Churikova, Stanislav Lyubshin ..."' not found in TSV file.
# Processing line 590...
# Line 592: 'Cidalc award,1973,"Speak, Little Mute Girl",Manuel Gutiérrez Aragón,"José Luis López Vázquez, Kiti Mánver, Francisco Algora ..."' not found in TSV file.
# Line 599: 'Interfilm award,1977,"The Devil, Probably",Robert Bresson,"Antoine Monnier, Nicolas Deguy, Tina Irissari ..."' not found in TSV file.
# Processing line 600...
# Line 609: 'Interfilm otto award,1987,The Teme,Gleb Panfilov,"Mikhail Ulyanov, Inna Churikova, Stanislav Lyubshin ..."' not found in TSV file.
# Processing line 610...
# Line 611: 'Interfilm otto award,1985,"Hail, Mary",Jean-Luc Godard,"Myriem Roussel, Thierry Rode, Philippe Lacoste ..."' not found in TSV file.
# Processing line 620...
# Processing line 630...
# Line 635: 'Interfilm award honorable,1988,Verónico Cruz,Miguel Pereira,"Juan José Camero, Gonzalo Morales, René Olaguivel ..."' not found in TSV file.
# Processing line 640...
# Processing line 650...
# Processing line 660...
# Line 662: 'Generation kplus crystal bear,2024,It’s Okay!,Kim Hye-young,"Lee Jeong-Ha, Jin Seo-yeon, Su-bin Chung ..."' not found in TSV file.
# Processing line 670...
# Line 674: 'Documentary special mention,2023,"Orlando, My Political Biography",Paul B. Preciado,Documentary' not found in TSV file.
# Total lines not found in TSV file: 47
# Lines not found in TSV file:
# Line 12: Golden bear,2014,"Black Coal, Thin Ice",Diao Yinan,"Liao Fan, Gwei Lun-Mei, Wang Xuebing ..."
# Line 21: Golden bear,2005,U-Carmen e-Khayelitsha,Mark Dornford-May,"Pauline Malefane, Andile Tshoni, Zweilungile Sidloyi ..."
# Line 39: Golden bear,1987,The Teme,Gleb Panfilov,"Mikhail Ulyanov, Inna Churikova, Stanislav Lyubshin ..."
# Line 45: Golden bear,1981,"Fast, Fast",Carlos Saura,"Berta Socuéllamos, José Antonio Valdelomar, Jesús Arias ..."
# Line 50: Golden bear,1976,"Buffalo Bill and the Indians, or Sitting Bull's History Lesson",Robert Altman,"Paul Newman, Burt Lancaster, Geraldine Chaplin ..."
# Line 83: Honourable mention,1991,Li Lianying: The Imperial Eunuch,Tian Zhuangzhuang,"Jiang Wen, Liu Xiaoqing, Xu Fan ..."
# Line 95: Special prize,1967,"Next Year, Same Time",Ulrich Schamoni,"Ulla Jacobsson, Sabine Sinjen, Hans-Dieter Schwarze ..."
# Line 104: Special prize,1958,"Two Eyes, Twelve Hands",Rajaram Vankudre Shantaram,"Rajaram Vankudre Shantaram, Sandhya, Ulhas ..."
# Line 111: Best director,2019,"I Was at Home, But",Angela Schanelec,"Maren Eggert, Jakob Lassalle, Clara Möller ..."
# Line 124: Best director,2006,The Road To Guantanamo,"Michael Winterbottom, Mat Whitecross","Riz Ahmed, Farhad Harun, Waqar Siddiqui ..."
# Line 141: Best director,1989,"I Love, You Love",Dusan Hanák,"Roman Klosowski, Iva Janzurová, Milan Jelic"
# Line 156: Best director,1968,Peppermint Frappe,Carlos Saura,"Geraldine Chaplin, José Luis López Vázquez, Alfredo Mayo ..."
# Line 170: Best leading performance,2023,"20,000 Species of Bees",Estibaliz Urresola Solaguren,"Sofía Otero, Patricia López Arnaiz, Ane Gabaraín ..."
# Line 174: Best actress,2019,"So Long, My Son",Wang Xiaoshuai,"Ai Liya, Du Jiang, Zhao Yanguozhang ..."
# Line 193: Best actress,2000,The Legends of Rita,Volker Schlöndorff,"Bibiana Beglau, Martin Wuttke, Nadja Uhl ..."
# Line 199: Best actress,1994,"Ladybird, Ladybird",Ken Loach,"Crissy Rock, Vladimir Vega, Ray Winstone ..."
# Line 263: Silver bear,1954,"Bread, Love and Dreams",Luigi Comencini,"Vittorio De Sica, Gina Lollobrigida, Roberto Risso ..."
# Line 267: Best actor,2019,"So Long, My Son",Wang Xiaoshuai,"Ai Liya, Du Jiang, Zhao Yanguozhang ..."
# Line 272: Best actor,2014,"Black Coal, Thin Ice",Diao Yinan,"Liao Fan, Gwei Lun-Mei, Wang Xuebing ..."
# Line 306: Best actor,1980,The Orchestra Conductor,Andrzej Wajda,"John Gielgud, Krystyna Janda, Andrzej Seweryn ..."
# Line 320: Best actor,1962,Mr. Hobbs Takes A Vacation,Henry Koster,"James Stewart, Maureen O'Hara, Lauri Peters ..."
# Line 364: Art contribution,2017,"Ana, My Love",Calin Peter Netzer,"Mircea Postelnicu, Diana Cavallioti, Carmen Tanase ..."
# Line 388: Art contribution,1988,Verónico Cruz,Miguel Pereira,"Juan José Camero, Gonzalo Morales, René Olaguivel ..."
# Line 394: Art contribution,1956,"The Blonde Witch, The Sorceress",André Michel,"Marina Vlady, Maurice Ronet, Nicole Courcel ..."
# Line 404: Bronze bear,1952,"Cry, the Beloved Country",Zoltan Korda,"Canada Lee, Charles Carson, Sidney Poitier ..."
# Line 448: Fipresci,1987,The Teme,Gleb Panfilov,"Mikhail Ulyanov, Inna Churikova, Stanislav Lyubshin ..."
# Line 462: Fipresci,1967,"Next Year, Same Time",Ulrich Schamoni,"Ulla Jacobsson, Sabine Sinjen, Hans-Dieter Schwarze ..."
# Line 472: Fipresci prize honourable,1989,"I Love, You Love",Dusan Hanák,"Roman Klosowski, Iva Janzurová, Milan Jelic"
# Line 509: Ocic award,1958,"Two Eyes, Twelve Hands",Rajaram Vankudre Shantaram,"Rajaram Vankudre Shantaram, Sandhya, Ulhas ..."
# Line 513: Ocic award honourable,1988,Verónico Cruz,Miguel Pereira,"Juan José Camero, Gonzalo Morales, René Olaguivel ..."
# Line 519: Ocic award recommendation,1983,"Pra Frente, Brasil",Roberto Farias,"Reginaldo Faria, Carlos Zara, Antonio Fagundes ..."
# Line 522: Ocic award recommendation,1977,"The Devil, Probably",Robert Bresson,"Antoine Monnier, Nicolas Deguy, Tina Irissari ..."
# Line 536: Alfred bauer prize,2011,"If Not Us, Who",Andres Veiel,"August Diehl, Lena Lauzemis, Susanne Lothar ..."
# Line 537: Alfred bauer prize,2010,"If I Want to Whistle, I Whistle",Florin Serban,"George Pistereanu, Ada Condeescu, Mihai Constantin ..."
# Line 540: Alfred bauer prize,2007,Is OK,Park Chan-wook,"Lim Soo-jung, Rain, Choi Hee-jin ..."
# Line 543: Alfred bauer prize,2004,Maria Full Of Grace,Joshua Marston,"Catalina Sandino Moreno, Yenny Paola Vega, Guilied López ..."
# Line 559: Blue angel award,2003,"Good Bye, Lenin!",Wolfgang Becker,"Daniel Brühl, Katrin Saß, Chulpan Khamatova ..."
# Line 562: Blue angel award,2000,The Legends of Rita,Volker Schlöndorff,"Bibiana Beglau, Martin Wuttke, Nadja Uhl ..."
# Line 575: Cicae award,1987,The Teme,Gleb Panfilov,"Mikhail Ulyanov, Inna Churikova, Stanislav Lyubshin ..."
# Line 582: Cidalc award,1987,The Teme,Gleb Panfilov,"Mikhail Ulyanov, Inna Churikova, Stanislav Lyubshin ..."
# Line 592: Cidalc award,1973,"Speak, Little Mute Girl",Manuel Gutiérrez Aragón,"José Luis López Vázquez, Kiti Mánver, Francisco Algora ..."
# Line 599: Interfilm award,1977,"The Devil, Probably",Robert Bresson,"Antoine Monnier, Nicolas Deguy, Tina Irissari ..."
# Line 609: Interfilm otto award,1987,The Teme,Gleb Panfilov,"Mikhail Ulyanov, Inna Churikova, Stanislav Lyubshin ..."
# Line 611: Interfilm otto award,1985,"Hail, Mary",Jean-Luc Godard,"Myriem Roussel, Thierry Rode, Philippe Lacoste ..."
# Line 635: Interfilm award honorable,1988,Verónico Cruz,Miguel Pereira,"Juan José Camero, Gonzalo Morales, René Olaguivel ..."
# Line 662: Generation kplus crystal bear,2024,It’s Okay!,Kim Hye-young,"Lee Jeong-Ha, Jin Seo-yeon, Su-bin Chung ..."
# Line 674: Documentary special mention,2023,"Orlando, My Political Biography",Paul B. Preciado,Documentary

# %%
import pandas as pd
import re

# CSV file path
csv_file = "C:/Users/frivo/Documents/csv coding project/cannes_film_affinity_winners.csv"

# TSV file path
tsv_file_path = "C:/Users/frivo/Downloads/title.akas.tsv/title.akas.tsv"

# Read all lines from the CSV file starting from the second line
with open(csv_file, 'r', encoding='utf-8') as file:
    csv_lines = file.readlines()[1:]

# Preprocess TSV file into a dictionary for faster lookups
tsv_lookup = {}
with open(tsv_file_path, 'r', encoding='utf-8') as tsv_file:
    for line in tsv_file:
        # Extract title from the TSV line
        movie_title_tsv = line.split('\t')[2].strip()  # Assuming the title is the third column
        
        # Remove non-alphanumeric characters from the title
        movie_title_tsv = re.sub(r'[^a-zA-Z0-9]', '', movie_title_tsv)

        # Store line in the dictionary
        tsv_lookup[movie_title_tsv] = line.strip()

# List to store found lines
found_lines = []

# List to store line numbers not found in TSV file
lines_not_found = []

# Search for each line from the CSV file in the TSV dictionary
for line_num, csv_line in enumerate(csv_lines, start=2):  # Start from line 2
    if line_num % 10 == 0:  # Print line number every 10 lines
        print(f"Processing line {line_num}...")

    # Extract movie title from the CSV line
    movie_title_csv = csv_line.strip().split(',')[2].strip()

    # Remove non-alphanumeric characters from the title
    movie_title_csv = re.sub(r'[^a-zA-Z0-9]', '', movie_title_csv)

    # Search for the movie title in the TSV dictionary
    tsv_line = tsv_lookup.get(movie_title_csv)
    if tsv_line:
        found_lines.append(tsv_line)
    else:
        lines_not_found.append((line_num, csv_line.strip()))
        print(f"Line {line_num}: '{csv_line.strip()}' not found in TSV file.")

# Write found lines to a CSV file
found_df = pd.DataFrame(found_lines, columns=['TSV Line'])
found_df.to_csv('found_lines_cannes.csv', index=False)

print("Total lines not found in TSV file:", len(lines_not_found))
print("Lines not found in TSV file:")
for line_num, line_content in lines_not_found:
    print(f"Line {line_num}: {line_content}")
# Out:
# Processing line 10...
# Line 17: 'Golden palm,2007,"4 Months, 3 Weeks & 2 Days",Cristian Mungiu,"Anamaria Marinca, Vlad Ivanov, Laura Vasiliu, Alexandru Potocean"' not found in TSV file.
# Processing line 20...
# Processing line 30...
# Processing line 40...
# Processing line 50...
# Processing line 60...
# Line 65: 'Golden palm,1958,The Cranes are Flying,Mikhail Kalatozov,"Tatyana Samojlova, Aleksey Batalov, Vasiliy Merkurev ..."' not found in TSV file.
# Processing line 70...
# Processing line 80...
# Processing line 90...
# Processing line 100...
# Processing line 110...
# Processing line 120...
# Processing line 130...
# Processing line 140...
# Processing line 150...
# Processing line 160...
# Processing line 170...
# Processing line 180...
# Processing line 190...
# Processing line 200...
# Processing line 210...
# Line 214: 'Best actor,2005,The Three Burials of Melquíades Estrada,Tommy Lee Jones,"Tommy Lee Jones, Barry Pepper, Julio Cedillo ..."' not found in TSV file.
# Processing line 220...
# Processing line 230...
# Processing line 240...
# Line 244: 'Best actor,1975,Sweet Smell of Woman,Dino Risi,"Vittorio Gassman, Agostina Belli, Alessandro Momo ..."' not found in TSV file.
# Processing line 250...
# Line 259: 'Best actor,1958,"The Long, Hot Summer",Martin Ritt,"Paul Newman, Joanne Woodward, Orson Welles ..."' not found in TSV file.
# Processing line 260...
# Processing line 270...
# Processing line 280...
# Processing line 290...
# Processing line 300...
# Processing line 310...
# Processing line 320...
# Processing line 330...
# Processing line 340...
# Processing line 350...
# Processing line 360...
# Line 361: 'Best screenplay,2005,The Three Burials of Melquíades Estrada,Tommy Lee Jones,"Tommy Lee Jones, Barry Pepper, Julio Cedillo ..."' not found in TSV file.
# Processing line 370...
# Processing line 380...
# Line 387: 'Best cinematography,1946,Portrait of Maria,Emilio Fernández,"Dolores del Rio, Pedro Armendáriz, Alberto Galán ..."' not found in TSV file.
# Processing line 390...
# Processing line 400...
# Line 400: 'Special mention,1958,The Cranes are Flying,Mikhail Kalatozov,"Tatyana Samojlova, Aleksey Batalov, Vasiliy Merkurev ..."' not found in TSV file.
# Processing line 410...
# Line 418: 'Fipresci,2010,You are all captains,Oliver Laxe,"Documentary,  Self: Shakib Ben Omar, Nabil Dourgal ..."' not found in TSV file.
# Processing line 420...
# Processing line 430...
# Line 433: 'Fipresci,1992,Dream Of Light,Víctor Erice,"Documentary,  Self: Antonio López"' not found in TSV file.
# Processing line 440...
# Processing line 450...
# Processing line 460...
# Processing line 470...
# Line 477: 'Camera d or,2008,Everybody Dies But Me   Special Mention,Valeriya Gai Germanika,"Polina Filonenko, Agniya Kuznetsova, Olga Shuvalova ..."' not found in TSV file.
# Processing line 480...
# Line 487: 'Camera d or,1997,Life of Jesus  Special Mention,Bruno Dumont,"David Douche, Marjorie Cottreel, Kader Chaatouf ..."' not found in TSV file.
# Processing line 490...
# Processing line 500...
# Processing line 510...
# Processing line 520...
# Line 524: 'Jury prize,2004,Flatlife  Special Mention,Jonas Geirnaert,Animation' not found in TSV file.
# Processing line 530...
# Line 531: 'Jury prize,1995,Donre Going to Die,Xavier Beauvois,"Xavier Beauvois, Chiara Mastroianni, Roschdy Zem ..."' not found in TSV file.
# Processing line 540...
# Line 543: 'Jury prize,1975,Florence + the Machine: Shake It Out,Dawn Shadforth,"Florence + The Machine, Florence Welch"' not found in TSV file.
# Line 545: 'Jury prize,1973,The Hour-Glass Sanatorium,Wojciech Has,"Jan Nowicki, Tadeusz Kondrat, Irena Orska ..."' not found in TSV file.
# Processing line 550...
# Processing line 560...
# Processing line 570...
# Line 573: 'Prize ecumenical,2004,Moolaadé  Special Mention,Ousmane Sembene,"Maimouna Hélène Diarra, Fatoumata Coulibaly, Salimata Traore ..."' not found in TSV file.
# Processing line 580...
# Processing line 590...
# Processing line 600...
# Processing line 610...
# Processing line 620...
# Processing line 630...
# Processing line 640...
# Line 645: 'Special award,1957,The Forty-first,Grigori Chukhrai,"Izolda Izvitskaya, Oleg Strizhenov, Nikolay Kryuchkov ..."' not found in TSV file.
# Processing line 650...
# Line 658: 'Ocic award,1962,Trial of Joan of Arc,Robert Bresson,"Florence Delay, Jean-Claude Fourneau, Marc Jacquier ..."' not found in TSV file.
# Processing line 660...
# Processing line 670...
# Line 670: 'Best short film,2021,All The Crows In The World,Yi Tang,"Xuanyu Chen, Baohe Xue"' not found in TSV file.
# Line 671: 'Best short film,2019,Monster God  Jury Special Mention,Agustina San Martín,"Camila Dobrusky, Emilio Vodanovich, Mariali Rubio, Isabella Rapazzo"' not found in TSV file.
# Line 673: 'Best short film,2017,The Ceiling  Jury Special Mention,Teppo Airaksinen,"Inna Bodson, Juho Milonoff, Pekka Strang"' not found in TSV file.
# Line 674: 'Best short film,2016,A moça que dançou com o Diabo   Special Mention,João Paulo Miranda Maria,' not found in TSV file.
# Processing line 680...
# Processing line 690...
# Processing line 700...
# Processing line 710...
# Processing line 720...
# Line 723: 'Best short film,1953,Crin-Blanc,Albert Lamorisse,"Alain Emery, Pierre Bestieux, Pascal Lamorisse ..."' not found in TSV file.
# Line 724: 'Short film jury prize,2021,Céu de Agosto  Special Mention,Jasmin Tenucci,"Badu Morais, Lilian Regina, Luci Pereira, Ernani Sanches"' not found in TSV file.
# Processing line 730...
# Processing line 740...
# Processing line 750...
# Processing line 760...
# Processing line 770...
# Processing line 780...
# Processing line 790...
# Processing line 800...
# Total lines not found in TSV file: 25
# Lines not found in TSV file:
# Line 17: Golden palm,2007,"4 Months, 3 Weeks & 2 Days",Cristian Mungiu,"Anamaria Marinca, Vlad Ivanov, Laura Vasiliu, Alexandru Potocean"
# Line 65: Golden palm,1958,The Cranes are Flying,Mikhail Kalatozov,"Tatyana Samojlova, Aleksey Batalov, Vasiliy Merkurev ..."
# Line 214: Best actor,2005,The Three Burials of Melquíades Estrada,Tommy Lee Jones,"Tommy Lee Jones, Barry Pepper, Julio Cedillo ..."
# Line 244: Best actor,1975,Sweet Smell of Woman,Dino Risi,"Vittorio Gassman, Agostina Belli, Alessandro Momo ..."
# Line 259: Best actor,1958,"The Long, Hot Summer",Martin Ritt,"Paul Newman, Joanne Woodward, Orson Welles ..."
# Line 361: Best screenplay,2005,The Three Burials of Melquíades Estrada,Tommy Lee Jones,"Tommy Lee Jones, Barry Pepper, Julio Cedillo ..."
# Line 387: Best cinematography,1946,Portrait of Maria,Emilio Fernández,"Dolores del Rio, Pedro Armendáriz, Alberto Galán ..."
# Line 400: Special mention,1958,The Cranes are Flying,Mikhail Kalatozov,"Tatyana Samojlova, Aleksey Batalov, Vasiliy Merkurev ..."
# Line 418: Fipresci,2010,You are all captains,Oliver Laxe,"Documentary,  Self: Shakib Ben Omar, Nabil Dourgal ..."
# Line 433: Fipresci,1992,Dream Of Light,Víctor Erice,"Documentary,  Self: Antonio López"
# Line 477: Camera d or,2008,Everybody Dies But Me   Special Mention,Valeriya Gai Germanika,"Polina Filonenko, Agniya Kuznetsova, Olga Shuvalova ..."
# Line 487: Camera d or,1997,Life of Jesus  Special Mention,Bruno Dumont,"David Douche, Marjorie Cottreel, Kader Chaatouf ..."
# Line 524: Jury prize,2004,Flatlife  Special Mention,Jonas Geirnaert,Animation
# Line 531: Jury prize,1995,Donre Going to Die,Xavier Beauvois,"Xavier Beauvois, Chiara Mastroianni, Roschdy Zem ..."
# Line 543: Jury prize,1975,Florence + the Machine: Shake It Out,Dawn Shadforth,"Florence + The Machine, Florence Welch"
# Line 545: Jury prize,1973,The Hour-Glass Sanatorium,Wojciech Has,"Jan Nowicki, Tadeusz Kondrat, Irena Orska ..."
# Line 573: Prize ecumenical,2004,Moolaadé  Special Mention,Ousmane Sembene,"Maimouna Hélène Diarra, Fatoumata Coulibaly, Salimata Traore ..."
# Line 645: Special award,1957,The Forty-first,Grigori Chukhrai,"Izolda Izvitskaya, Oleg Strizhenov, Nikolay Kryuchkov ..."
# Line 658: Ocic award,1962,Trial of Joan of Arc,Robert Bresson,"Florence Delay, Jean-Claude Fourneau, Marc Jacquier ..."
# Line 670: Best short film,2021,All The Crows In The World,Yi Tang,"Xuanyu Chen, Baohe Xue"
# Line 671: Best short film,2019,Monster God  Jury Special Mention,Agustina San Martín,"Camila Dobrusky, Emilio Vodanovich, Mariali Rubio, Isabella Rapazzo"
# Line 673: Best short film,2017,The Ceiling  Jury Special Mention,Teppo Airaksinen,"Inna Bodson, Juho Milonoff, Pekka Strang"
# Line 674: Best short film,2016,A moça que dançou com o Diabo   Special Mention,João Paulo Miranda Maria,
# Line 723: Best short film,1953,Crin-Blanc,Albert Lamorisse,"Alain Emery, Pierre Bestieux, Pascal Lamorisse ..."
# Line 724: Short film jury prize,2021,Céu de Agosto  Special Mention,Jasmin Tenucci,"Badu Morais, Lilian Regina, Luci Pereira, Ernani Sanches"

# %%
import pandas as pd
import re

# CSV file path
csv_file = "C:/Users/frivo/Documents/csv coding project/mar_film_affinity_winners.csv"

# TSV file path
tsv_file_path = "C:/Users/frivo/Downloads/title.akas.tsv/title.akas.tsv"

# Read all lines from the CSV file starting from the second line
# Read all lines from the CSV file starting from the second line
with open(csv_file, 'r', encoding='utf-8') as file:
    csv_lines = file.readlines()[1:]

# Preprocess TSV file into a dictionary for faster lookups
tsv_lookup = {}
with open(tsv_file_path, 'r', encoding='utf-8') as tsv_file:
    for line in tsv_file:
        # Extract title from the TSV line
        movie_title_tsv = line.split('\t')[2].strip()  # Assuming the title is the third column
        
        # Remove non-alphanumeric characters from the title
        movie_title_tsv = re.sub(r'[^a-zA-Z0-9]', '', movie_title_tsv)

        # Store line in the dictionary
        tsv_lookup[movie_title_tsv] = line.strip()

# List to store found lines
found_lines = []

# List to store line numbers not found in TSV file
lines_not_found = []

# Search for each line from the CSV file in the TSV dictionary
for line_num, csv_line in enumerate(csv_lines, start=2):  # Start from line 2
    if line_num % 10 == 0:  # Print line number every 10 lines
        print(f"Processing line {line_num}...")

    # Extract movie title from the CSV line
    movie_title_csv = csv_line.strip().split(',')[2].strip()

    # Remove non-alphanumeric characters from the title
    movie_title_csv = re.sub(r'[^a-zA-Z0-9]', '', movie_title_csv)

    # Search for the movie title in the TSV dictionary
    tsv_line = tsv_lookup.get(movie_title_csv)
    if tsv_line:
        found_lines.append(tsv_line)
    else:
        lines_not_found.append((line_num, csv_line.strip()))
        print(f"Line {line_num}: '{csv_line.strip()}' not found in TSV file.")

# Write found lines to a CSV file
found_df = pd.DataFrame(found_lines, columns=['TSV Line'])
found_df.to_csv('found_lines_mar.csv', index=False)

print("Total lines not found in TSV file:", len(lines_not_found))
print("Lines not found in TSV file:")
for line_num, line_content in lines_not_found:
    print(f"Line {line_num}: {line_content}")
# Out:
# Processing line 10...
# Line 11: 'Best film,2014,Come to my Voice,Huseyin Karabey,"Tuncay Akdemir, Selim Bulut, Sabahettin DAG ..."' not found in TSV file.
# Processing line 20...
# Processing line 30...
# Line 34: 'Best film,1963,Angyalok Földje,György Révész,"Tamás Végvári, Klári Tolnay, Ferenc Zenthe ..."' not found in TSV file.
# Processing line 40...
# Processing line 50...
# Line 59: 'Special jury award,1996,Warshot,Heiner Stadler,"Billy Clarke, Calvin Burke, Claude Channice ..."' not found in TSV file.
# Processing line 60...
# Line 66: 'Best director,2019,"I Was at Home, But",Angela Schanelec,"Maren Eggert, Jakob Lassalle, Clara Möller ..."' not found in TSV file.
# Line 67: 'Best director,2018,What You Gonna Do When The World's On Fire?,Roberto Minervini,"Documentary,  Self: Judy Hill, Dorothy Hill, Michael Nelson ..."' not found in TSV file.
# Processing line 70...
# Processing line 80...
# Line 86: 'Best director,1998,You laugh,"Paolo Taviani, Vittorio Taviani","Turi Ferro, Antonio Albanese, Lello Arena ..."' not found in TSV file.
# Line 88: 'Best director,1996,"East Palace, West Palace",Zhang Yuan,"Si Han, Hu Jun, Zhao Wei, Jing Ye"' not found in TSV file.
# Processing line 90...
# Processing line 100...
# Processing line 110...
# Line 118: 'Best actress,2018,What You Gonna Do When The World's On Fire?,Roberto Minervini,"Documentary,  Self: Judy Hill, Dorothy Hill, Michael Nelson ..."' not found in TSV file.
# Processing line 120...
# Processing line 130...
# Processing line 140...
# Processing line 150...
# Line 157: 'Best screenplay,2005,The Downfall: Hitler and the End of the Third Reich,Oliver Hirschbiegel,"Bruno Ganz, Alexandra Maria Lara, Corinna Harfouch ..."' not found in TSV file.
# Processing line 160...
# Line 165: 'Best screenplay,1996,"East Palace, West Palace",Zhang Yuan,"Si Han, Hu Jun, Zhao Wei, Jing Ye"' not found in TSV file.
# Line 166: 'Best iberoamerican,2023,Otro sol,Francisco Rodriguez Teare,"Documentary, Iván Cáceres, Claudio Palape ..."' not found in TSV file.
# Processing line 170...
# Line 174: 'Best iberoamerican,2015,Santa Teresa y otras historias,Nelson Carlo de los Santos Arias,"Documentary,  Self: Marie Aimee Montalembert, Cristina Kahlo ..."' not found in TSV file.
# Line 175: 'Best iberoamerican,2014,"Branco sai, preto fica",Adirley Queirós,"Marquim do Tropa, Shockito, Dilmar Durães ..."' not found in TSV file.
# Line 179: 'Best iberoamerican,2010,Love in transit,Lucas Blanco,"Sabrina Garciarena, Lucas Crespi, Damián Canduci ..."' not found in TSV file.
# Processing line 180...
# Line 184: 'Best iberoamerican,2005,Almost Two Brothers,Lucía Murat,"Caco Ciocler, Flavio Bauraqui, Werner Schünemann ..."' not found in TSV file.
# Processing line 190...
# Processing line 200...
# Processing line 210...
# Line 215: 'Special jury mention,1996,"East Palace, West Palace",Zhang Yuan,"Si Han, Hu Jun, Zhao Wei, Jing Ye"' not found in TSV file.
# Processing line 220...
# Line 223: 'Best argentinian film,2018,El árbol negro,"Máximo Ciambella, Damián Coluccio","Documentary,  Self: Martín Barrios, Valentín Suárez"' not found in TSV file.
# Line 229: 'Best argentinian director,2019,The Poets Visit Juana Bignozzi,"Laura Citarella, Mercedes Halfon","Documentary,  Self: Martín Rodríguez, Marcelina Jarma ..."' not found in TSV file.
# Processing line 230...
# Line 237: 'Fipresci,2010,The ways of wine,Nicolás Carreras,"Charlie Arturaola, Pandora Anwyl, Donato de Santis ..."' not found in TSV file.
# Processing line 240...
# Processing line 250...
# Processing line 260...
# Total lines not found in TSV file: 19
# Lines not found in TSV file:
# Line 11: Best film,2014,Come to my Voice,Huseyin Karabey,"Tuncay Akdemir, Selim Bulut, Sabahettin DAG ..."
# Line 34: Best film,1963,Angyalok Földje,György Révész,"Tamás Végvári, Klári Tolnay, Ferenc Zenthe ..."
# Line 59: Special jury award,1996,Warshot,Heiner Stadler,"Billy Clarke, Calvin Burke, Claude Channice ..."
# Line 66: Best director,2019,"I Was at Home, But",Angela Schanelec,"Maren Eggert, Jakob Lassalle, Clara Möller ..."
# Line 67: Best director,2018,What You Gonna Do When The World's On Fire?,Roberto Minervini,"Documentary,  Self: Judy Hill, Dorothy Hill, Michael Nelson ..."
# Line 86: Best director,1998,You laugh,"Paolo Taviani, Vittorio Taviani","Turi Ferro, Antonio Albanese, Lello Arena ..."
# Line 88: Best director,1996,"East Palace, West Palace",Zhang Yuan,"Si Han, Hu Jun, Zhao Wei, Jing Ye"
# Line 118: Best actress,2018,What You Gonna Do When The World's On Fire?,Roberto Minervini,"Documentary,  Self: Judy Hill, Dorothy Hill, Michael Nelson ..."
# Line 157: Best screenplay,2005,The Downfall: Hitler and the End of the Third Reich,Oliver Hirschbiegel,"Bruno Ganz, Alexandra Maria Lara, Corinna Harfouch ..."
# Line 165: Best screenplay,1996,"East Palace, West Palace",Zhang Yuan,"Si Han, Hu Jun, Zhao Wei, Jing Ye"
# Line 166: Best iberoamerican,2023,Otro sol,Francisco Rodriguez Teare,"Documentary, Iván Cáceres, Claudio Palape ..."
# Line 174: Best iberoamerican,2015,Santa Teresa y otras historias,Nelson Carlo de los Santos Arias,"Documentary,  Self: Marie Aimee Montalembert, Cristina Kahlo ..."
# Line 175: Best iberoamerican,2014,"Branco sai, preto fica",Adirley Queirós,"Marquim do Tropa, Shockito, Dilmar Durães ..."
# Line 179: Best iberoamerican,2010,Love in transit,Lucas Blanco,"Sabrina Garciarena, Lucas Crespi, Damián Canduci ..."
# Line 184: Best iberoamerican,2005,Almost Two Brothers,Lucía Murat,"Caco Ciocler, Flavio Bauraqui, Werner Schünemann ..."
# Line 215: Special jury mention,1996,"East Palace, West Palace",Zhang Yuan,"Si Han, Hu Jun, Zhao Wei, Jing Ye"
# Line 223: Best argentinian film,2018,El árbol negro,"Máximo Ciambella, Damián Coluccio","Documentary,  Self: Martín Barrios, Valentín Suárez"
# Line 229: Best argentinian director,2019,The Poets Visit Juana Bignozzi,"Laura Citarella, Mercedes Halfon","Documentary,  Self: Martín Rodríguez, Marcelina Jarma ..."
# Line 237: Fipresci,2010,The ways of wine,Nicolás Carreras,"Charlie Arturaola, Pandora Anwyl, Donato de Santis ..."

# %%
import pandas as pd
import re 
# CSV file path
csv_file = "C:/Users/frivo/Documents/csv coding project/shanghai_film_affinity_winners.csv"

# TSV file path
tsv_file_path = "C:/Users/frivo/Downloads/title.akas.tsv/title.akas.tsv"

# Read all lines from the CSV file starting from the second line
# Read all lines from the CSV file starting from the second line
with open(csv_file, 'r', encoding='utf-8') as file:
    csv_lines = file.readlines()[1:]

# Preprocess TSV file into a dictionary for faster lookups
tsv_lookup = {}
with open(tsv_file_path, 'r', encoding='utf-8') as tsv_file:
    for line in tsv_file:
        # Extract title from the TSV line
        movie_title_tsv = line.split('\t')[2].strip()  # Assuming the title is the third column
        
        # Remove non-alphanumeric characters from the title
        movie_title_tsv = re.sub(r'[^a-zA-Z0-9]', '', movie_title_tsv)

        # Store line in the dictionary
        tsv_lookup[movie_title_tsv] = line.strip()

# List to store found lines
found_lines = []

# List to store line numbers not found in TSV file
lines_not_found = []

# Search for each line from the CSV file in the TSV dictionary
for line_num, csv_line in enumerate(csv_lines, start=2):  # Start from line 2
    if line_num % 10 == 0:  # Print line number every 10 lines
        print(f"Processing line {line_num}...")

    # Extract movie title from the CSV line
    movie_title_csv = csv_line.strip().split(',')[2].strip()

    # Remove non-alphanumeric characters from the title
    movie_title_csv = re.sub(r'[^a-zA-Z0-9]', '', movie_title_csv)

    # Search for the movie title in the TSV dictionary
    tsv_line = tsv_lookup.get(movie_title_csv)
    if tsv_line:
        found_lines.append(tsv_line)
    else:
        lines_not_found.append((line_num, csv_line.strip()))
        print(f"Line {line_num}: '{csv_line.strip()}' not found in TSV file.")

# Write found lines to a CSV file
found_df = pd.DataFrame(found_lines, columns=['TSV Line'])
found_df.to_csv('found_lines_shanghai.csv', index=False)

print("Total lines not found in TSV file:", len(lines_not_found))
print("Lines not found in TSV file:")
for line_num, line_content in lines_not_found:
    print(f"Line {line_num}: {line_content}")
# Out:
# Processing line 10...
# Line 12: 'Best film,2011,Hayde bre,Orhan Oguz,"Sevket Emrulla, Nilüfer Açikalin, Ilker Inanoglu ..."' not found in TSV file.
# Line 16: 'Best film,2007,According to the plan,Franziska Meletzky,"Dagmar Manzel, Corinna Harfouch, Kirsten Block ..."' not found in TSV file.
# Processing line 20...
# Processing line 30...
# Processing line 40...
# Processing line 50...
# Processing line 60...
# Processing line 70...
# Line 75: 'Best actor,2023,Dust To Dust,Jonathan Li,"Da Peng, Yao Chang, Lan Ke ..."' not found in TSV file.
# Processing line 80...
# Line 85: 'Best actor,2011,Hayde bre,Orhan Oguz,"Sevket Emrulla, Nilüfer Açikalin, Ilker Inanoglu ..."' not found in TSV file.
# Processing line 90...
# Processing line 100...
# Processing line 110...
# Line 113: 'Best actress,2007,According to the plan,Franziska Meletzky,"Dagmar Manzel, Corinna Harfouch, Kirsten Block ..."' not found in TSV file.
# Processing line 120...
# Processing line 130...
# Processing line 140...
# Processing line 150...
# Processing line 160...
# Processing line 170...
# Line 173: 'Best technology,1999,William Shakespeares Dream,Michael Hoffman,"Kevin Kline, Michelle Pfeiffer, Rupert Everett ..."' not found in TSV file.
# Line 174: 'Artistic achievement,2023,"Good Autumn, Mommy",Shizhong Chen,"Bai Ke, Lang Yueting, Shu Qi, Benyu Zhang"' not found in TSV file.
# Processing line 180...
# Processing line 190...
# Processing line 200...
# Total lines not found in TSV file: 7
# Lines not found in TSV file:
# Line 12: Best film,2011,Hayde bre,Orhan Oguz,"Sevket Emrulla, Nilüfer Açikalin, Ilker Inanoglu ..."
# Line 16: Best film,2007,According to the plan,Franziska Meletzky,"Dagmar Manzel, Corinna Harfouch, Kirsten Block ..."
# Line 75: Best actor,2023,Dust To Dust,Jonathan Li,"Da Peng, Yao Chang, Lan Ke ..."
# Line 85: Best actor,2011,Hayde bre,Orhan Oguz,"Sevket Emrulla, Nilüfer Açikalin, Ilker Inanoglu ..."
# Line 113: Best actress,2007,According to the plan,Franziska Meletzky,"Dagmar Manzel, Corinna Harfouch, Kirsten Block ..."
# Line 173: Best technology,1999,William Shakespeares Dream,Michael Hoffman,"Kevin Kline, Michelle Pfeiffer, Rupert Everett ..."
# Line 174: Artistic achievement,2023,"Good Autumn, Mommy",Shizhong Chen,"Bai Ke, Lang Yueting, Shu Qi, Benyu Zhang"

# %%
import pandas as pd
import re
# CSV file path
csv_file = "C:/Users/frivo/Documents/csv coding project/sitges_film_affinity_winners.csv"

# TSV file path
tsv_file_path = "C:/Users/frivo/Downloads/title.akas.tsv/title.akas.tsv"

# Read all lines from the CSV file starting from the second line
with open(csv_file, 'r', encoding='utf-8') as file:
    csv_lines = file.readlines()[1:]

# Preprocess TSV file into a dictionary for faster lookups
tsv_lookup = {}
with open(tsv_file_path, 'r', encoding='utf-8') as tsv_file:
    for line in tsv_file:
        # Extract title from the TSV line
        movie_title_tsv = line.split('\t')[2].strip()  # Assuming the title is the third column
        
        # Remove non-alphanumeric characters from the title
        movie_title_tsv = re.sub(r'[^a-zA-Z0-9]', '', movie_title_tsv)

        # Store line in the dictionary
        tsv_lookup[movie_title_tsv] = line.strip()

# List to store found lines
found_lines = []

# List to store line numbers not found in TSV file
lines_not_found = []

# Search for each line from the CSV file in the TSV dictionary
for line_num, csv_line in enumerate(csv_lines, start=2):  # Start from line 2
    if line_num % 10 == 0:  # Print line number every 10 lines
        print(f"Processing line {line_num}...")

    # Extract movie title from the CSV line
    movie_title_csv = csv_line.strip().split(',')[2].strip()

    # Remove non-alphanumeric characters from the title
    movie_title_csv = re.sub(r'[^a-zA-Z0-9]', '', movie_title_csv)

    # Search for the movie title in the TSV dictionary
    tsv_line = tsv_lookup.get(movie_title_csv)
    if tsv_line:
        found_lines.append(tsv_line)
    else:
        lines_not_found.append((line_num, csv_line.strip()))
        print(f"Line {line_num}: '{csv_line.strip()}' not found in TSV file.")

# Write found lines to a CSV file
found_df = pd.DataFrame(found_lines, columns=['TSV Line'])
found_df.to_csv('found_lines_sitges.csv', index=False)

print("Total lines not found in TSV file:", len(lines_not_found))
print("Lines not found in TSV file:")
for line_num, line_content in lines_not_found:
    print(f"Line {line_num}: {line_content}")
# Out:
# Processing line 10...
# Processing line 20...
# Processing line 30...
# Processing line 40...
# Processing line 50...
# Processing line 60...
# Processing line 70...
# Processing line 80...
# Processing line 90...
# Line 98: 'Best director,1986,The Legend Of Suram Fortress,"Sergei Parajanov, Dodo Abashidze","Veriko Andjaparidze, Tamari Tsitsishvili, Dodo Abashidze ..."' not found in TSV file.
# Processing line 100...
# Processing line 110...
# Processing line 120...
# Processing line 130...
# Processing line 140...
# Processing line 150...
# Line 153: 'Best actor,1984,The Brother From Another Planet,John Sayles,"Joe Morton, Tom Wright, Caroline Aaron ..."' not found in TSV file.
# Processing line 160...
# Processing line 170...
# Processing line 180...
# Processing line 190...
# Processing line 200...
# Processing line 210...
# Processing line 220...
# Processing line 230...
# Line 236: 'Best screenplay,2007,Is OK,Park Chan-wook,"Lim Soo-jung, Rain, Choi Hee-jin ..."' not found in TSV file.
# Processing line 240...
# Line 247: 'Best screenplay,1995,Donre Going,Eliseo Subiela,"Darío Grandinetti, Mariana Arias, Oscar Martínez ..."' not found in TSV file.
# Processing line 250...
# Line 257: 'Best screenplay,1984,The Brother From Another Planet,John Sayles,"Joe Morton, Tom Wright, Caroline Aaron ..."' not found in TSV file.
# Processing line 260...
# Processing line 270...
# Processing line 280...
# Line 288: 'Best cinematography,2008,The Brøken,Sean Ellis,"Lena Headey, Ulrich Thomsen, Melvil Poupaud ..."' not found in TSV file.
# Processing line 290...
# Line 291: 'Best cinematography,2005,Seven swords,Tsui Hark,"Leon Lai, Charlie Yeung, Donnie Yen ..."' not found in TSV file.
# Line 299: 'Best cinematography,1997,99.9 The Frequency of Horror,Agustí Villaronga,"María Barranco, Terele Pávez, Ruth Gabriel ..."' not found in TSV file.
# Processing line 300...
# Processing line 310...
# Line 318: 'Best cinematography,1978,Adele Hasn't Had Her Supper Yet,Oldrich Lipský,"Michal Docolomanský, Rudolf Hrusínsky, Milos Kopecký ..."' not found in TSV file.
# Processing line 320...
# Processing line 330...
# Processing line 340...
# Processing line 350...
# Processing line 360...
# Processing line 370...
# Processing line 380...
# Processing line 390...
# Processing line 400...
# Processing line 410...
# Processing line 420...
# Processing line 430...
# Processing line 440...
# Processing line 450...
# Processing line 460...
# Processing line 470...
# Line 475: 'Best animated feature,2016,Your name,Makoto Shinkai,Animation' not found in TSV file.
# Processing line 480...
# Line 489: 'Best animated feature,2002,"Mercano, el marciano",Juan Antin,Animation' not found in TSV file.
# Processing line 490...
# Processing line 500...
# Processing line 510...
# Line 518: 'Best short film,2023,I'm not a Robot,Victoria Warmerdam,"Ellen Parren, Henry van Loon, Thekla Reuten ..."' not found in TSV file.
# Processing line 520...
# Processing line 530...
# Processing line 540...
# Line 548: 'Special mention noves visions,2023,Passage House,Isti Madarász,"Attila Árpa, Péter Bárnai, Kata Dobó ..."' not found in TSV file.
# Processing line 550...
# Processing line 560...
# Processing line 570...
# Total lines not found in TSV file: 13
# Lines not found in TSV file:
# Line 98: Best director,1986,The Legend Of Suram Fortress,"Sergei Parajanov, Dodo Abashidze","Veriko Andjaparidze, Tamari Tsitsishvili, Dodo Abashidze ..."
# Line 153: Best actor,1984,The Brother From Another Planet,John Sayles,"Joe Morton, Tom Wright, Caroline Aaron ..."
# Line 236: Best screenplay,2007,Is OK,Park Chan-wook,"Lim Soo-jung, Rain, Choi Hee-jin ..."
# Line 247: Best screenplay,1995,Donre Going,Eliseo Subiela,"Darío Grandinetti, Mariana Arias, Oscar Martínez ..."
# Line 257: Best screenplay,1984,The Brother From Another Planet,John Sayles,"Joe Morton, Tom Wright, Caroline Aaron ..."
# Line 288: Best cinematography,2008,The Brøken,Sean Ellis,"Lena Headey, Ulrich Thomsen, Melvil Poupaud ..."
# Line 291: Best cinematography,2005,Seven swords,Tsui Hark,"Leon Lai, Charlie Yeung, Donnie Yen ..."
# Line 299: Best cinematography,1997,99.9 The Frequency of Horror,Agustí Villaronga,"María Barranco, Terele Pávez, Ruth Gabriel ..."
# Line 318: Best cinematography,1978,Adele Hasn't Had Her Supper Yet,Oldrich Lipský,"Michal Docolomanský, Rudolf Hrusínsky, Milos Kopecký ..."
# Line 475: Best animated feature,2016,Your name,Makoto Shinkai,Animation
# Line 489: Best animated feature,2002,"Mercano, el marciano",Juan Antin,Animation
# Line 518: Best short film,2023,I'm not a Robot,Victoria Warmerdam,"Ellen Parren, Henry van Loon, Thekla Reuten ..."
# Line 548: Special mention noves visions,2023,Passage House,Isti Madarász,"Attila Árpa, Péter Bárnai, Kata Dobó ..."

# %%
import pandas as pd
import re

# CSV file path
csv_file = "C:/Users/frivo/Documents/csv coding project/tokyo_film_affinity_winners.csv"

# TSV file path
tsv_file_path = "C:/Users/frivo/Downloads/title.akas.tsv/title.akas.tsv"

# Read all lines from the CSV file starting from the second line
with open(csv_file, 'r', encoding='utf-8') as file:
    csv_lines = file.readlines()[1:]

# Preprocess TSV file into a dictionary for faster lookups
tsv_lookup = {}
with open(tsv_file_path, 'r', encoding='utf-8') as tsv_file:
    for line in tsv_file:
        # Extract title from the TSV line
        movie_title_tsv = line.split('\t')[2].strip()  # Assuming the title is the third column
        
        # Remove non-alphanumeric characters from the title
        movie_title_tsv = re.sub(r'[^a-zA-Z0-9]', '', movie_title_tsv)

        # Store line in the dictionary
        tsv_lookup[movie_title_tsv] = line.strip()

# List to store found lines
found_lines = []

# List to store line numbers not found in TSV file
lines_not_found = []

# Search for each line from the CSV file in the TSV dictionary
for line_num, csv_line in enumerate(csv_lines, start=2):  # Start from line 2
    if line_num % 10 == 0:  # Print line number every 10 lines
        print(f"Processing line {line_num}...")

    # Extract movie title from the CSV line
    movie_title_csv = csv_line.strip().split(',')[2].strip()

    # Remove non-alphanumeric characters from the title
    movie_title_csv = re.sub(r'[^a-zA-Z0-9]', '', movie_title_csv)

    # Search for the movie title in the TSV dictionary
    tsv_line = tsv_lookup.get(movie_title_csv)
    if tsv_line:
        found_lines.append(tsv_line)
    else:
        lines_not_found.append((line_num, csv_line.strip()))
        print(f"Line {line_num}: '{csv_line.strip()}' not found in TSV file.")

# Write found lines to a CSV file
found_df = pd.DataFrame(found_lines, columns=['TSV Line'])
found_df.to_csv('found_lines_tokyo.csv', index=False)

print("Total lines not found in TSV file:", len(lines_not_found))
print("Lines not found in TSV file:")
for line_num, line_content in lines_not_found:
    print(f"Line {line_num}: {line_content}")
# Out:
# Total lines not found in TSV file: 0
# Lines not found in TSV file:

# %%
import pandas as pd
import re

# CSV file path
csv_file = "C:/Users/frivo/Documents/csv coding project/toronto_film_affinity_winners.csv"

# TSV file path
tsv_file_path = "C:/Users/frivo/Downloads/title.akas.tsv/title.akas.tsv"

# Read all lines from the CSV file starting from the second line
with open(csv_file, 'r', encoding='utf-8') as file:
    csv_lines = file.readlines()[1:]

# Preprocess TSV file into a dictionary for faster lookups
tsv_lookup = {}
with open(tsv_file_path, 'r', encoding='utf-8') as tsv_file:
    for line in tsv_file:
        # Extract title from the TSV line
        movie_title_tsv = line.split('\t')[2].strip()  # Assuming the title is the third column
        
        # Remove non-alphanumeric characters from the title
        movie_title_tsv = re.sub(r'[^a-zA-Z0-9]', '', movie_title_tsv)

        # Store line in the dictionary
        tsv_lookup[movie_title_tsv] = line.strip()

# List to store found lines
found_lines = []

# List to store line numbers not found in TSV file
lines_not_found = []

# Search for each line from the CSV file in the TSV dictionary
for line_num, csv_line in enumerate(csv_lines, start=2):  # Start from line 2
    if line_num % 10 == 0:  # Print line number every 10 lines
        print(f"Processing line {line_num}...")

    # Extract movie title from the CSV line
    movie_title_csv = csv_line.strip().split(',')[2].strip()

    # Remove non-alphanumeric characters from the title
    movie_title_csv = re.sub(r'[^a-zA-Z0-9]', '', movie_title_csv)

    # Search for the movie title in the TSV dictionary
    tsv_line = tsv_lookup.get(movie_title_csv)
    if tsv_line:
        found_lines.append(tsv_line)
    else:
        lines_not_found.append((line_num, csv_line.strip()))
        print(f"Line {line_num}: '{csv_line.strip()}' not found in TSV file.")

# Write found lines to a CSV file
found_df = pd.DataFrame(found_lines, columns=['TSV Line'])
found_df.to_csv('found_lines_toronto.csv', index=False)

print("Total lines not found in TSV file:", len(lines_not_found))
print("Lines not found in TSV file:")
for line_num, line_content in lines_not_found:
    print(f"Line {line_num}: {line_content}")
# Out:
# Line 8: 'Choice award,2017,"Three Billboards Outside Ebbing, Missouri",Martin McDonagh,"Frances McDormand, Woody Harrelson, Sam Rockwell ..."' not found in TSV file.
# Processing line 10...
# Processing line 20...
# Processing line 30...
# Processing line 40...
# Processing line 50...
# Processing line 60...
# Processing line 70...
# Line 70: 'Best canadian film,2014,Félix and Meira,Maxime Giroux,"Martin Dubreuil, Hadas Yaron, Luzer Twersky ..."' not found in TSV file.
# Processing line 80...
# Processing line 90...
# Processing line 100...
# Line 106: 'Best canadian first film,2017,LukI,Wayne Wapeemukwa,"Angel Gates, Joe Buffalo, Ken Harrower ..."' not found in TSV file.
# Processing line 110...
# Processing line 120...
# Line 129: 'Platform mention,2019,"Anne at 13,000 Ft.",Kazik Radwanski,"Deragh Campbell, Lawrene Denkers, Matt Johnson ..."' not found in TSV file.
# Processing line 130...
# Processing line 140...
# Processing line 150...
# Processing line 160...
# Processing line 170...
# Processing line 180...
# Total lines not found in TSV file: 4
# Lines not found in TSV file:
# Line 8: Choice award,2017,"Three Billboards Outside Ebbing, Missouri",Martin McDonagh,"Frances McDormand, Woody Harrelson, Sam Rockwell ..."
# Line 70: Best canadian film,2014,Félix and Meira,Maxime Giroux,"Martin Dubreuil, Hadas Yaron, Luzer Twersky ..."
# Line 106: Best canadian first film,2017,LukI,Wayne Wapeemukwa,"Angel Gates, Joe Buffalo, Ken Harrower ..."
# Line 129: Platform mention,2019,"Anne at 13,000 Ft.",Kazik Radwanski,"Deragh Campbell, Lawrene Denkers, Matt Johnson ..."

# %%
# Out:
# Processing line 10...
# Processing line 20...
# Processing line 30...
# Line 35: 'Golden lion,1990,Rosencrantz and Guildenstern Are Dead,Tom Stoppard,"Gary Oldman, Tim Roth, Richard Dreyfuss ..."' not found in TSV file.
# Processing line 40...
# Line 46: 'Golden lion,1968,Artists under the Big Top: Perplexed,Alexander Kluge,"Hannelore Hoger, Sigi Graue, Alfred Edel ..."' not found in TSV file.
# Line 49: 'Golden lion,1965,Sandra of a Thousand Delights,Luchino Visconti,"Claudia Cardinale, Jean Sorel, Michael Craig ..."' not found in TSV file.
# Processing line 50...
# Processing line 60...
# Processing line 70...
# Processing line 80...
# Line 88: 'Silver lion,2023,Me Captain,Matteo Garrone,"Seydou Sarr, Moustapha Fall, Issaka Sawadogo ..."' not found in TSV file.
# Processing line 90...
# Processing line 100...
# Line 100: 'Silver lion,2011,"People Mountain, People Sea",Cai Shangjun,"Chen Jianbin, Tao Hong, Wu Xiubo ..."' not found in TSV file.
# Processing line 110...
# Processing line 120...
# Processing line 130...
# Line 132: 'Special jury prize,2023,The Green Border,Agnieszka Holland,"Behi Djanati Atai, Agata Kulesza, Piotr Stramowski ..."' not found in TSV file.
# Processing line 140...
# Processing line 150...
# Processing line 160...
# Line 164: 'Special jury prize,1991,A divina comédia,Manoel de Oliveira,"María de Medeiros, Miguel Guilherme, Luis Miguel Cintra ..."' not found in TSV file.
# Processing line 170...
# Line 170: 'Special jury prize,1985,"Tangos, the Exile of Gardel",Fernando E. Solanas,"Marie Laforêt, Philippe Léotard, Miguel Ángel Solá ..."' not found in TSV file.
# Line 176: 'Special jury prize,1967,China is near,Marco Bellocchio,"Glauco Mauri, Elda Tattoli, Paolo Graziosi ..."' not found in TSV file.
# Processing line 180...
# Processing line 190...
# Processing line 200...
# Processing line 210...
# Processing line 220...
# Line 222: 'Best actress,1988,The Story of Women,Claude Chabrol,"Isabelle Huppert, François Cluzet, Marie Trintignant ..."' not found in TSV file.
# Processing line 230...
# Processing line 240...
# Line 246: 'Best actress,1947,Angelina: Member of Parliament,Luigi Zampa,"Anna Magnani, Nando Bruno, Ave Ninchi ..."' not found in TSV file.
# Processing line 250...
# Processing line 260...
# Processing line 270...
# Line 271: 'Best actor,2007,The Assassination of Jesse James By The Coward Robert Ford,Andrew Dominik,"Brad Pitt, Casey Affleck, Sam Rockwell ..."' not found in TSV file.
# Processing line 280...
# Processing line 290...
# Line 298: 'Best actor,1966,Almost a man,Vittorio De Seta,"Jacques Perrin, Lea Padovani, Gianni Garko ..."' not found in TSV file.
# Processing line 300...
# Processing line 310...
# Line 310: 'Best actor,1954,Grisbi: Hands Off the Loot,Jacques Becker,"Jean Gabin, René Dary, Dora Doll ..."' not found in TSV file.
# Processing line 320...
# Processing line 330...
# Line 334: 'Best screenplay,2017,"Three Billboards Outside Ebbing, Missouri",Martin McDonagh,"Frances McDormand, Woody Harrelson, Sam Rockwell ..."' not found in TSV file.
# Processing line 340...
# Processing line 350...
# Processing line 360...
# Processing line 370...
# Line 376: 'Best cinematography,1934,Dood Water,Gerard Rutten,"Jan Musch, Theo de Maal, Betsy Ranucci-Beckman ..."' not found in TSV file.
# Processing line 380...
# Processing line 390...
# Processing line 400...
# Line 401: 'Fipresci,2002,11'01 - September 11,"Samira Makhmalbaf, Claude Lelouch, Youssef Chahine","Documentary,  Self: Ernest Borgnine, Ken Ogata ..."' not found in TSV file.
# Processing line 410...
# Line 411: 'Fipresci,1989,"Dekalog 1: I Am the Lord Thy God, Thou Shalt Have No Other God But Me",Krzysztof Kieślowski,"Henryk Baranowski, Wojciech Klata, Maja Komorowska ..."' not found in TSV file.
# Processing line 420...
# Processing line 430...
# Line 435: 'Orizzonti best direction,2023,Paradise is Burning,Mika Gustafson,"Bianca Delbravo, Marta Oldenburg, Dilvin Asaad ..."' not found in TSV file.
# Processing line 440...
# Processing line 450...
# Line 452: 'Unesco,2002,11'01 - September 11,"Samira Makhmalbaf, Claude Lelouch, Youssef Chahine","Documentary,  Self: Ernest Borgnine, Ken Ogata ..."' not found in TSV file.
# Processing line 460...
# Line 464: 'Best first work,1963,Le Joli Mai,"Chris Marker, Pierre Lhomme","Documentary,  Self: Chris Marker, Yves Montand, Simone Signoret"' not found in TSV file.
# Processing line 470...
# Total lines not found in TSV file: 21
# Lines not found in TSV file:
# Line 35: Golden lion,1990,Rosencrantz and Guildenstern Are Dead,Tom Stoppard,"Gary Oldman, Tim Roth, Richard Dreyfuss ..."
# Line 46: Golden lion,1968,Artists under the Big Top: Perplexed,Alexander Kluge,"Hannelore Hoger, Sigi Graue, Alfred Edel ..."
# Line 49: Golden lion,1965,Sandra of a Thousand Delights,Luchino Visconti,"Claudia Cardinale, Jean Sorel, Michael Craig ..."
# Line 88: Silver lion,2023,Me Captain,Matteo Garrone,"Seydou Sarr, Moustapha Fall, Issaka Sawadogo ..."
# Line 100: Silver lion,2011,"People Mountain, People Sea",Cai Shangjun,"Chen Jianbin, Tao Hong, Wu Xiubo ..."
# Line 132: Special jury prize,2023,The Green Border,Agnieszka Holland,"Behi Djanati Atai, Agata Kulesza, Piotr Stramowski ..."
# Line 164: Special jury prize,1991,A divina comédia,Manoel de Oliveira,"María de Medeiros, Miguel Guilherme, Luis Miguel Cintra ..."
# Line 170: Special jury prize,1985,"Tangos, the Exile of Gardel",Fernando E. Solanas,"Marie Laforêt, Philippe Léotard, Miguel Ángel Solá ..."
# Line 176: Special jury prize,1967,China is near,Marco Bellocchio,"Glauco Mauri, Elda Tattoli, Paolo Graziosi ..."
# Line 222: Best actress,1988,The Story of Women,Claude Chabrol,"Isabelle Huppert, François Cluzet, Marie Trintignant ..."
# Line 246: Best actress,1947,Angelina: Member of Parliament,Luigi Zampa,"Anna Magnani, Nando Bruno, Ave Ninchi ..."
# Line 271: Best actor,2007,The Assassination of Jesse James By The Coward Robert Ford,Andrew Dominik,"Brad Pitt, Casey Affleck, Sam Rockwell ..."
# Line 298: Best actor,1966,Almost a man,Vittorio De Seta,"Jacques Perrin, Lea Padovani, Gianni Garko ..."
# Line 310: Best actor,1954,Grisbi: Hands Off the Loot,Jacques Becker,"Jean Gabin, René Dary, Dora Doll ..."
# Line 334: Best screenplay,2017,"Three Billboards Outside Ebbing, Missouri",Martin McDonagh,"Frances McDormand, Woody Harrelson, Sam Rockwell ..."
# Line 376: Best cinematography,1934,Dood Water,Gerard Rutten,"Jan Musch, Theo de Maal, Betsy Ranucci-Beckman ..."
# Line 401: Fipresci,2002,11'01 - September 11,"Samira Makhmalbaf, Claude Lelouch, Youssef Chahine","Documentary,  Self: Ernest Borgnine, Ken Ogata ..."
# Line 411: Fipresci,1989,"Dekalog 1: I Am the Lord Thy God, Thou Shalt Have No Other God But Me",Krzysztof Kieślowski,"Henryk Baranowski, Wojciech Klata, Maja Komorowska ..."
# Line 435: Orizzonti best direction,2023,Paradise is Burning,Mika Gustafson,"Bianca Delbravo, Marta Oldenburg, Dilvin Asaad ..."
# Line 452: Unesco,2002,11'01 - September 11,"Samira Makhmalbaf, Claude Lelouch, Youssef Chahine","Documentary,  Self: Ernest Borgnine, Ken Ogata ..."
# Line 464: Best first work,1963,Le Joli Mai,"Chris Marker, Pierre Lhomme","Documentary,  Self: Chris Marker, Yves Montand, Simone Signoret"

# %%
import pandas as pd
import re

# CSV file path
csv_file = "C:/Users/frivo/Downloads/academy_awards_film_affinity_winners.csv"

# TSV file path
tsv_file_path = "C:/Users/frivo/Downloads/title.akas.tsv/title.akas.tsv"

# Read all lines from the CSV file starting from the second line
with open(csv_file, 'r', encoding='utf-8') as file:
    csv_lines = file.readlines()[1:]

# Preprocess TSV file into a dictionary for faster lookups
tsv_lookup = {}
with open(tsv_file_path, 'r', encoding='utf-8') as tsv_file:
    for line in tsv_file:
        # Extract title from the TSV line
        movie_title_tsv = line.split('\t')[2].strip()  # Assuming the title is the third column
        
        # Remove non-alphanumeric characters from the title
        movie_title_tsv = re.sub(r'[^a-zA-Z0-9]', '', movie_title_tsv)

        # Store line in the dictionary
        tsv_lookup[movie_title_tsv] = line.strip()

# List to store found lines
found_lines = []

# List to store line numbers not found in TSV file
lines_not_found = []

# Search for each line from the CSV file in the TSV dictionary
for line_num, csv_line in enumerate(csv_lines, start=2):  # Start from line 2
    if line_num % 10 == 0:  # Print line number every 10 lines
        print(f"Processing line {line_num}...")

    # Extract movie title from the CSV line excluding anything within parentheses
    movie_title_csv = re.sub(r'\([^()]*\)', '', csv_line.strip().split(',')[2].strip())

    # Remove non-alphanumeric characters from the title
    movie_title_csv = re.sub(r'[^a-zA-Z0-9]', '', movie_title_csv)

    # Search for the movie title in the TSV dictionary
    tsv_line = tsv_lookup.get(movie_title_csv)
    if tsv_line:
        found_lines.append(','.join(tsv_line.split('\t')))  # Joining the data with commas
    else:
        lines_not_found.append((line_num, csv_line.strip()))
        print(f"Line {line_num}: '{csv_line.strip()}' not found in TSV file.")

# Write found lines to a CSV file
found_df = pd.DataFrame(found_lines, columns=['TSV Line'])
found_df.to_csv('found_lines_academy_award.csv', index=False)

print("Total lines not found in TSV file:", len(lines_not_found))
print("Lines not found in TSV file:")
for line_num, line_content in lines_not_found:
    print(f"Line {line_num}: {line_content}")
# Out:
# Processing line 10...
# Processing line 20...
# Processing line 30...
# Processing line 40...
# Processing line 50...
# Processing line 60...
# Processing line 70...
# Processing line 80...
# Processing line 90...
# Processing line 100...
# Processing line 110...
# Processing line 120...
# Processing line 130...
# Processing line 140...
# Processing line 150...
# Processing line 160...
# Processing line 170...
# Processing line 180...
# Processing line 190...
# Processing line 200...
# Line 200: 'Best leading actress,2018,"Three Billboards Outside Ebbing, Missouri",Martin McDonagh,"Frances McDormand, Woody Harrelson, Sam Rockwell ..."' not found in TSV file.
# Processing line 210...
# Processing line 220...
# Processing line 230...
# Processing line 240...
# Processing line 250...
# Processing line 260...
# Processing line 270...
# Line 277: 'Best leading actress,1941,Kitty Foyle: The Natural History of a Woman,Sam Wood,"Ginger Rogers, Dennis Morgan, James Craig ..."' not found in TSV file.
# Processing line 280...
# Processing line 290...
# Processing line 300...
# Processing line 310...
# Processing line 320...
# Processing line 330...
# Processing line 340...
# Processing line 350...
# Processing line 360...
# Processing line 370...
# Processing line 380...
# Processing line 390...
# Line 392: 'Best supporting actor,2018,"Three Billboards Outside Ebbing, Missouri",Martin McDonagh,"Frances McDormand, Woody Harrelson, Sam Rockwell ..."' not found in TSV file.
# Processing line 400...
# Processing line 410...
# Processing line 420...
# Processing line 430...
# Processing line 440...
# Line 440: 'Best supporting actor,1970,"They Shoot Horses, Don't They?",Sydney Pollack,"Jane Fonda, Michael Sarrazin, Susannah York ..."' not found in TSV file.
# Processing line 450...
# Processing line 460...
# Processing line 470...
# Processing line 480...
# Processing line 490...
# Processing line 500...
# Line 503: 'Best supporting actress,1995,Bullets over Broadway,Woody Allen,"John Cusack, Dianne Wiest, Chazz Palminteri ..."' not found in TSV file.
# Processing line 510...
# Processing line 520...
# Processing line 530...
# Processing line 540...
# Processing line 550...
# Processing line 560...
# Processing line 570...
# Processing line 580...
# Processing line 590...
# Processing line 600...
# Processing line 610...
# Processing line 620...
# Processing line 630...
# Processing line 640...
# Processing line 650...
# Processing line 660...
# Processing line 670...
# Processing line 680...
# Processing line 690...
# Processing line 700...
# Processing line 710...
# Processing line 720...
# Processing line 730...
# Processing line 740...
# Line 746: 'Best adapted screenplay,1987,A Room With a View,James Ivory,"Helena Bonham Carter, Maggie Smith, Denholm Elliott ..."' not found in TSV file.
# Processing line 750...
# Processing line 760...
# Processing line 770...
# Processing line 780...
# Processing line 790...
# Processing line 800...
# Processing line 810...
# Processing line 820...
# Processing line 830...
# Processing line 840...
# Processing line 850...
# Processing line 860...
# Processing line 870...
# Processing line 880...
# Processing line 890...
# Processing line 900...
# Processing line 910...
# Processing line 920...
# Processing line 930...
# Processing line 940...
# Processing line 950...
# Processing line 960...
# Processing line 970...
# Processing line 980...
# Processing line 990...
# Processing line 1000...
# Processing line 1010...
# Line 1019: 'Best cinematography color,1944,Phantom Of The Opera,Arthur Lubin,"Nelson Eddy, Susanna Foster, Claude Rains ..."' not found in TSV file.
# Processing line 1020...
# Processing line 1030...
# Processing line 1040...
# Processing line 1050...
# Processing line 1060...
# Processing line 1070...
# Processing line 1080...
# Processing line 1090...
# Processing line 1100...
# Processing line 1110...
# Processing line 1120...
# Processing line 1130...
# Processing line 1140...
# Line 1142: 'Best score drama comedy,1956,Love is a Many-Splendored Thing,Henry King,"Jennifer Jones, William Holden, Isobel Elsom ..."' not found in TSV file.
# Processing line 1150...
# Processing line 1160...
# Processing line 1170...
# Processing line 1180...
# Processing line 1190...
# Processing line 1200...
# Processing line 1210...
# Processing line 1220...
# Processing line 1230...
# Processing line 1240...
# Line 1244: 'Best song,1956,Love is a Many-Splendored Thing,Henry King,"Jennifer Jones, William Holden, Isobel Elsom ..."' not found in TSV file.
# Line 1249: 'Best song,1951,"Captain Carey, U.S.A.",Mitchell Leisen,"Alan Ladd, Wanda Hendrix, Francis Lederer ..."' not found in TSV file.
# Processing line 1250...
# Processing line 1260...
# Processing line 1270...
# Processing line 1280...
# Processing line 1290...
# Processing line 1300...
# Processing line 1310...
# Processing line 1320...
# Line 1320: 'Best art direction,1987,A Room With a View,James Ivory,"Helena Bonham Carter, Maggie Smith, Denholm Elliott ..."' not found in TSV file.
# Processing line 1330...
# Processing line 1340...
# Processing line 1350...
# Processing line 1360...
# Processing line 1370...
# Line 1375: 'Best art direction color,1944,Phantom Of The Opera,Arthur Lubin,"Nelson Eddy, Susanna Foster, Claude Rains ..."' not found in TSV file.
# Processing line 1380...
# Processing line 1390...
# Processing line 1400...
# Processing line 1410...
# Processing line 1420...
# Processing line 1430...
# Line 1436: 'Best costume design,1995,"The Adventures of Priscilla, Queen of the Desert",Stephan Elliott,"Terence Stamp, Hugo Weaving, Guy Pearce ..."' not found in TSV file.
# Processing line 1440...
# Line 1444: 'Best costume design,1987,A Room With a View,James Ivory,"Helena Bonham Carter, Maggie Smith, Denholm Elliott ..."' not found in TSV file.
# Processing line 1450...
# Processing line 1460...
# Processing line 1470...
# Line 1475: 'Best costume design color,1956,Love is a Many-Splendored Thing,Henry King,"Jennifer Jones, William Holden, Isobel Elsom ..."' not found in TSV file.
# Processing line 1480...
# Processing line 1490...
# Processing line 1500...
# Processing line 1510...
# Line 1518: 'Best makeup,2006,"The Chronicles of Narnia: The Lion, The Witch and the Wardrobe",Andrew Adamson,"Georgie Henley, William Moseley, Skandar Keynes ..."' not found in TSV file.
# Line 1519: 'Best makeup,2005,Lemony Snicket's A Series Of Unfortunate Events,Brad Silberling,"Jim Carrey, Liam Aiken, Emily Browning ..."' not found in TSV file.
# Processing line 1520...
# Processing line 1530...
# Processing line 1540...
# Processing line 1550...
# Processing line 1560...
# Processing line 1570...
# Processing line 1580...
# Processing line 1590...
# Processing line 1600...
# Processing line 1610...
# Processing line 1620...
# Processing line 1630...
# Processing line 1640...
# Line 1647: 'Best sound editing,2007,Letters From Iwo Jima,Clint Eastwood,"Ken Watanabe, Kazunari Ninomiya, Tsuyoshi Ihara ..."' not found in TSV file.
# Processing line 1650...
# Processing line 1660...
# Processing line 1670...
# Line 1677: 'Best sound editing,1964,"It's a Mad, Mad, Mad, Mad World",Stanley Kramer,"Spencer Tracy, Milton Berle, Sid Caesar ..."' not found in TSV file.
# Processing line 1680...
# Processing line 1690...
# Processing line 1700...
# Processing line 1710...
# Processing line 1720...
# Processing line 1730...
# Processing line 1740...
# Processing line 1750...
# Line 1751: 'Best special effects,1945,Thirty Seconds over Tokyo,Mervyn LeRoy,"Spencer Tracy, Van Johnson, Robert Walker ..."' not found in TSV file.
# Processing line 1760...
# Processing line 1770...
# Processing line 1780...
# Line 1780: 'Best short film animated,2024,WAR IS OVER! (S),Dave Mullins,Animation' not found in TSV file.
# Processing line 1790...
# Line 1796: 'Best short film animated,2008,Peter & The Wolf,Suzie Templeton,Animation' not found in TSV file.
# Processing line 1800...
# Processing line 1810...
# Processing line 1820...
# Processing line 1830...
# Processing line 1840...
# Processing line 1850...
# Processing line 1860...
# Line 1862: 'Best short film animated,1942,Walt Disney's Mickey Mouse: Lend a Paw (S),Clyde Geronimi,Animation' not found in TSV file.
# Processing line 1870...
# Line 1874: 'Best documentary feature,2022,"Summer of Soul (...Or, When the Revolution Could Not Be Televised)",Questlove,"Documentary, Stevie Wonder, B.B. King ..."' not found in TSV file.
# Processing line 1880...
# Line 1880: 'Best documentary feature,2016,Raw: The Amy Winehouse Story,Asif Kapadia,"Documentary,  Self: Amy Winehouse, Mitch Winehouse ..."' not found in TSV file.
# Processing line 1890...
# Processing line 1900...
# Line 1908: 'Best documentary feature,1988,The Ten-Year Lunch: The Wit and Legend of the Algonquin Round Table,Aviva Slesin,Documentary' not found in TSV file.
# Processing line 1910...
# Line 1913: 'Best documentary feature,1983,The Fifth Estate: Just Another Missing Kid (TV),John Zaritsky,Documentary' not found in TSV file.
# Processing line 1920...
# Line 1927: 'Best documentary feature,1969,Journey into Self,Bill McGaw,"Documentary,  Self: Richard Farson, Carl Rogers, Stanley Kramer"' not found in TSV file.
# Processing line 1930...
# Processing line 1940...
# Line 1940: 'Best documentary feature,1956,The Unconquered: Helen Keller in Her Story,Nancy Hamilton,"Documentary,  Self: Katharine Cornell, Helen Keller, Polly Thompson"' not found in TSV file.
# Processing line 1950...
# Line 1957: 'Best short film documentary,2020,Learning to Skateboard in a Warzone (If You're a Girl),Carol Dysinger,Documentary' not found in TSV file.
# Processing line 1960...
# Processing line 1970...
# Processing line 1980...
# Processing line 1990...
# Line 1996: 'Best short film,2001,I want to be... (Quiero ser),Florian Gallenberger,"Emilio Perez, Luis Fernando Peña"' not found in TSV file.
# Line 1997: 'Best short film,2000,My Mother Dreams the Satan's Disciples In New York,Barbara Schock,"Helen Stenborg, Patricia Dunnock, Scott Sowers ..."' not found in TSV file.
# Processing line 2000...
# Processing line 2010...
# Processing line 2020...
# Processing line 2030...
# Processing line 2040...
# Line 2040: 'Best short film,1957,The Bespoke Overcoat  Two-Reel,Jack Clayton,"Alfie Bass, David Kossoff, Alan Tilvern, Alf Dean"' not found in TSV file.
# Line 2041: 'Best short film,1956,The Face of Lincoln (S) (S) Two-Reel,Edward Freed,"Documentary,  Self: Robert Merrell Gage"' not found in TSV file.
# Line 2042: 'Best short film,1955,This Mechanical Age (S) One-Reel,Robert Youngson,"Documentary,  Voice: Dwight Weist, Ward Wilson"' not found in TSV file.
# Line 2043: 'Best short film,1954,Bear Country  Two-Reel,James Algar,Documentary' not found in TSV file.
# Line 2044: 'Best short film,1953,Water Birds  Two-Reel,Ben Sharpsteen,"Documentary,  Self: Winston Hibler"' not found in TSV file.
# Line 2045: 'Best short film,1952,Nature's Half Acre  Two-Reel,James Algar,"Documentary,  Self: Winston Hibler"' not found in TSV file.
# Line 2046: 'Best short film,1951,Beaver Valley  Two-Reel,James Algar,"Documentary,  Self: Winston Hibler"' not found in TSV file.
# Line 2047: 'Best short film,1950,Van Gogh (S) Two-Reel,Alain Resnais,Documentary' not found in TSV file.
# Line 2048: 'Best short film,1949,Seal Island  Two-Reel,James Algar,"Documentary,  Self: Winston Hibler"' not found in TSV file.
# Processing line 2050...
# Line 2050: 'Best short film,1947,Facing Your Danger (S) (S) One-Reel,Edwin E. Olsen,"Documentary,  Self: Knox Manning, Norman Nevills, Edwin E. Olsen"' not found in TSV file.
# Line 2051: 'Best short film,1946,Star in the Night (S) Two-Reel,Don Siegel,"Donald Woods, J. Carrol Naish, Rosina Galli ..."' not found in TSV file.
# Processing line 2060...
# Processing line 2070...
# Total lines not found in TSV file: 43
# Lines not found in TSV file:
# Line 200: Best leading actress,2018,"Three Billboards Outside Ebbing, Missouri",Martin McDonagh,"Frances McDormand, Woody Harrelson, Sam Rockwell ..."
# Line 277: Best leading actress,1941,Kitty Foyle: The Natural History of a Woman,Sam Wood,"Ginger Rogers, Dennis Morgan, James Craig ..."
# Line 392: Best supporting actor,2018,"Three Billboards Outside Ebbing, Missouri",Martin McDonagh,"Frances McDormand, Woody Harrelson, Sam Rockwell ..."
# Line 440: Best supporting actor,1970,"They Shoot Horses, Don't They?",Sydney Pollack,"Jane Fonda, Michael Sarrazin, Susannah York ..."
# Line 503: Best supporting actress,1995,Bullets over Broadway,Woody Allen,"John Cusack, Dianne Wiest, Chazz Palminteri ..."
# Line 746: Best adapted screenplay,1987,A Room With a View,James Ivory,"Helena Bonham Carter, Maggie Smith, Denholm Elliott ..."
# Line 1019: Best cinematography color,1944,Phantom Of The Opera,Arthur Lubin,"Nelson Eddy, Susanna Foster, Claude Rains ..."
# Line 1142: Best score drama comedy,1956,Love is a Many-Splendored Thing,Henry King,"Jennifer Jones, William Holden, Isobel Elsom ..."
# Line 1244: Best song,1956,Love is a Many-Splendored Thing,Henry King,"Jennifer Jones, William Holden, Isobel Elsom ..."
# Line 1249: Best song,1951,"Captain Carey, U.S.A.",Mitchell Leisen,"Alan Ladd, Wanda Hendrix, Francis Lederer ..."
# Line 1320: Best art direction,1987,A Room With a View,James Ivory,"Helena Bonham Carter, Maggie Smith, Denholm Elliott ..."
# Line 1375: Best art direction color,1944,Phantom Of The Opera,Arthur Lubin,"Nelson Eddy, Susanna Foster, Claude Rains ..."
# Line 1436: Best costume design,1995,"The Adventures of Priscilla, Queen of the Desert",Stephan Elliott,"Terence Stamp, Hugo Weaving, Guy Pearce ..."
# Line 1444: Best costume design,1987,A Room With a View,James Ivory,"Helena Bonham Carter, Maggie Smith, Denholm Elliott ..."
# Line 1475: Best costume design color,1956,Love is a Many-Splendored Thing,Henry King,"Jennifer Jones, William Holden, Isobel Elsom ..."
# Line 1518: Best makeup,2006,"The Chronicles of Narnia: The Lion, The Witch and the Wardrobe",Andrew Adamson,"Georgie Henley, William Moseley, Skandar Keynes ..."
# Line 1519: Best makeup,2005,Lemony Snicket's A Series Of Unfortunate Events,Brad Silberling,"Jim Carrey, Liam Aiken, Emily Browning ..."
# Line 1647: Best sound editing,2007,Letters From Iwo Jima,Clint Eastwood,"Ken Watanabe, Kazunari Ninomiya, Tsuyoshi Ihara ..."
# Line 1677: Best sound editing,1964,"It's a Mad, Mad, Mad, Mad World",Stanley Kramer,"Spencer Tracy, Milton Berle, Sid Caesar ..."
# Line 1751: Best special effects,1945,Thirty Seconds over Tokyo,Mervyn LeRoy,"Spencer Tracy, Van Johnson, Robert Walker ..."
# Line 1780: Best short film animated,2024,WAR IS OVER! (S),Dave Mullins,Animation
# Line 1796: Best short film animated,2008,Peter & The Wolf,Suzie Templeton,Animation
# Line 1862: Best short film animated,1942,Walt Disney's Mickey Mouse: Lend a Paw (S),Clyde Geronimi,Animation
# Line 1874: Best documentary feature,2022,"Summer of Soul (...Or, When the Revolution Could Not Be Televised)",Questlove,"Documentary, Stevie Wonder, B.B. King ..."
# Line 1880: Best documentary feature,2016,Raw: The Amy Winehouse Story,Asif Kapadia,"Documentary,  Self: Amy Winehouse, Mitch Winehouse ..."
# Line 1908: Best documentary feature,1988,The Ten-Year Lunch: The Wit and Legend of the Algonquin Round Table,Aviva Slesin,Documentary
# Line 1913: Best documentary feature,1983,The Fifth Estate: Just Another Missing Kid (TV),John Zaritsky,Documentary
# Line 1927: Best documentary feature,1969,Journey into Self,Bill McGaw,"Documentary,  Self: Richard Farson, Carl Rogers, Stanley Kramer"
# Line 1940: Best documentary feature,1956,The Unconquered: Helen Keller in Her Story,Nancy Hamilton,"Documentary,  Self: Katharine Cornell, Helen Keller, Polly Thompson"
# Line 1957: Best short film documentary,2020,Learning to Skateboard in a Warzone (If You're a Girl),Carol Dysinger,Documentary
# Line 1996: Best short film,2001,I want to be... (Quiero ser),Florian Gallenberger,"Emilio Perez, Luis Fernando Peña"
# Line 1997: Best short film,2000,My Mother Dreams the Satan's Disciples In New York,Barbara Schock,"Helen Stenborg, Patricia Dunnock, Scott Sowers ..."
# Line 2040: Best short film,1957,The Bespoke Overcoat  Two-Reel,Jack Clayton,"Alfie Bass, David Kossoff, Alan Tilvern, Alf Dean"
# Line 2041: Best short film,1956,The Face of Lincoln (S) (S) Two-Reel,Edward Freed,"Documentary,  Self: Robert Merrell Gage"
# Line 2042: Best short film,1955,This Mechanical Age (S) One-Reel,Robert Youngson,"Documentary,  Voice: Dwight Weist, Ward Wilson"
# Line 2043: Best short film,1954,Bear Country  Two-Reel,James Algar,Documentary
# Line 2044: Best short film,1953,Water Birds  Two-Reel,Ben Sharpsteen,"Documentary,  Self: Winston Hibler"
# Line 2045: Best short film,1952,Nature's Half Acre  Two-Reel,James Algar,"Documentary,  Self: Winston Hibler"
# Line 2046: Best short film,1951,Beaver Valley  Two-Reel,James Algar,"Documentary,  Self: Winston Hibler"
# Line 2047: Best short film,1950,Van Gogh (S) Two-Reel,Alain Resnais,Documentary
# Line 2048: Best short film,1949,Seal Island  Two-Reel,James Algar,"Documentary,  Self: Winston Hibler"
# Line 2050: Best short film,1947,Facing Your Danger (S) (S) One-Reel,Edwin E. Olsen,"Documentary,  Self: Knox Manning, Norman Nevills, Edwin E. Olsen"
# Line 2051: Best short film,1946,Star in the Night (S) Two-Reel,Don Siegel,"Donald Woods, J. Carrol Naish, Rosina Galli ..."

# %%
import pandas as pd
import re

# CSV file path
csv_file = "C:/Users/frivo/Downloads/golden_globes_film_affinity_winners.csv"

# TSV file path
tsv_file_path = "C:/Users/frivo/Downloads/title.akas.tsv/title.akas.tsv"

# Read all lines from the CSV file starting from the second line
with open(csv_file, 'r', encoding='utf-8') as file:
    csv_lines = file.readlines()[1:]

# Preprocess TSV file into a dictionary for faster lookups
tsv_lookup = {}
with open(tsv_file_path, 'r', encoding='utf-8') as tsv_file:
    for line in tsv_file:
        # Extract title from the TSV line
        movie_title_tsv = line.split('\t')[2].strip()  # Assuming the title is the third column
        
        # Remove non-alphanumeric characters from the title
        movie_title_tsv = re.sub(r'[^a-zA-Z0-9]', '', movie_title_tsv)

        # Store line in the dictionary
        tsv_lookup[movie_title_tsv] = line.strip()

# List to store found lines
found_lines = []

# List to store line numbers not found in TSV file
lines_not_found = []

# Search for each line from the CSV file in the TSV dictionary
for line_num, csv_line in enumerate(csv_lines, start=2):  # Start from line 2
    if line_num % 10 == 0:  # Print line number every 10 lines
        print(f"Processing line {line_num}...")

    # Extract movie title from the CSV line excluding anything within parentheses
    movie_title_csv = re.sub(r'\([^()]*\)', '', csv_line.strip().split(',')[2].strip())

    # Remove non-alphanumeric characters from the title
    movie_title_csv = re.sub(r'[^a-zA-Z0-9]', '', movie_title_csv)

    # Search for the movie title in the TSV dictionary
    tsv_line = tsv_lookup.get(movie_title_csv)
    if tsv_line:
        found_lines.append(','.join(tsv_line.split('\t')))  # Joining the data with commas
    else:
        lines_not_found.append((line_num, csv_line.strip()))
        print(f"Line {line_num}: '{csv_line.strip()}' not found in TSV file.")

# Write found lines to a CSV file
found_df = pd.DataFrame(found_lines, columns=['TSV Line'])
found_df.to_csv('found_lines_golden_globes_award.csv', index=False)

print("Total lines not found in TSV file:", len(lines_not_found))
print("Lines not found in TSV file:")
for line_num, line_content in lines_not_found:
    print(f"Line {line_num}: {line_content}")
# Out:
# Line 8: 'Best picture drama,2018,"Three Billboards Outside Ebbing, Missouri",Martin McDonagh,"Frances McDormand, Woody Harrelson, Sam Rockwell ..."' not found in TSV file.
# Processing line 10...
# Processing line 20...
# Processing line 30...
# Processing line 40...
# Processing line 50...
# Processing line 60...
# Processing line 70...
# Processing line 80...
# Processing line 90...
# Processing line 100...
# Processing line 110...
# Processing line 120...
# Processing line 130...
# Processing line 140...
# Processing line 150...
# Processing line 160...
# Processing line 170...
# Processing line 180...
# Processing line 190...
# Processing line 200...
# Processing line 210...
# Processing line 220...
# Processing line 230...
# Processing line 240...
# Processing line 250...
# Processing line 260...
# Processing line 270...
# Processing line 280...
# Processing line 290...
# Processing line 300...
# Processing line 310...
# Processing line 320...
# Line 324: 'Best leading actress drama,2018,"Three Billboards Outside Ebbing, Missouri",Martin McDonagh,"Frances McDormand, Woody Harrelson, Sam Rockwell ..."' not found in TSV file.
# Processing line 330...
# Line 334: 'Best leading actress drama,2008,Away From Her,Sarah Polley,"Julie Christie, Gordon Pinsent, Olympia Dukakis ..."' not found in TSV file.
# Processing line 340...
# Processing line 350...
# Processing line 360...
# Processing line 370...
# Processing line 380...
# Processing line 390...
# Line 396: 'Best leading actor comedy,2022,"tick, tick... Boom!",Lin-Manuel Miranda,"Andrew Garfield, Alexandra Shipp, Robin de Jesus ..."' not found in TSV file.
# Processing line 400...
# Processing line 410...
# Processing line 420...
# Processing line 430...
# Processing line 440...
# Processing line 450...
# Processing line 460...
# Processing line 470...
# Processing line 480...
# Processing line 490...
# Processing line 500...
# Processing line 510...
# Line 510: 'Best leading actress comedy,1982,Pennies From Heaven,Herbert Ross,"Steve Martin, Christopher Walken, Bernadette Peters ..."' not found in TSV file.
# Processing line 520...
# Processing line 530...
# Processing line 540...
# Processing line 550...
# Line 558: 'Best supporting actor,2018,"Three Billboards Outside Ebbing, Missouri",Martin McDonagh,"Frances McDormand, Woody Harrelson, Sam Rockwell ..."' not found in TSV file.
# Processing line 560...
# Processing line 570...
# Processing line 580...
# Line 587: 'Best supporting actor,1989,Tucker: the Man and His Dream,Francis Ford Coppola,"Jeff Bridges, Joan Allen, Martin Landau ..."' not found in TSV file.
# Processing line 590...
# Processing line 600...
# Line 606: 'Best supporting actor,1970,"They Shoot Horses, Don't They?",Sydney Pollack,"Jane Fonda, Michael Sarrazin, Susannah York ..."' not found in TSV file.
# Processing line 610...
# Line 610: 'Best supporting actor,1966,The Spy Who Came In from the Cold,Martin Ritt,"Richard Burton, Claire Bloom, Oskar Werner ..."' not found in TSV file.
# Processing line 620...
# Processing line 630...
# Processing line 640...
# Processing line 650...
# Processing line 660...
# Line 662: 'Best supporting actress,1995,Bullets over Broadway,Woody Allen,"John Cusack, Dianne Wiest, Chazz Palminteri ..."' not found in TSV file.
# Processing line 670...
# Line 670: 'Best supporting actress,1987,A Room With a View,James Ivory,"Helena Bonham Carter, Maggie Smith, Denholm Elliott ..."' not found in TSV file.
# Processing line 680...
# Processing line 690...
# Processing line 700...
# Processing line 710...
# Processing line 720...
# Processing line 730...
# Processing line 740...
# Processing line 750...
# Processing line 760...
# Processing line 770...
# Processing line 780...
# Line 786: 'Best screenplay,2018,"Three Billboards Outside Ebbing, Missouri",Martin McDonagh,"Frances McDormand, Woody Harrelson, Sam Rockwell ..."' not found in TSV file.
# Processing line 790...
# Processing line 800...
# Processing line 810...
# Processing line 820...
# Processing line 830...
# Processing line 840...
# Processing line 850...
# Processing line 860...
# Processing line 870...
# Processing line 880...
# Processing line 890...
# Processing line 900...
# Processing line 910...
# Processing line 920...
# Processing line 930...
# Processing line 940...
# Processing line 950...
# Processing line 960...
# Line 963: 'Best original song,1991,Young Guns 2: Blaze of Glory,Geoff Murphy,"Emilio Estévez, Kiefer Sutherland, Lou Diamond Phillips ..."' not found in TSV file.
# Processing line 970...
# Processing line 980...
# Processing line 990...
# Line 999: 'Best film promoting international unders,1956,Love is a Many-Splendored Thing,Henry King,"Jennifer Jones, William Holden, Isobel Elsom ..."' not found in TSV file.
# Processing line 1000...
# Processing line 1010...
# Processing line 1020...
# Line 1026: 'Best foreign language film,2007,Letters From Iwo Jima,Clint Eastwood,"Ken Watanabe, Kazunari Ninomiya, Tsuyoshi Ihara ..."' not found in TSV file.
# Processing line 1030...
# Processing line 1040...
# Processing line 1050...
# Processing line 1060...
# Processing line 1070...
# Processing line 1080...
# Processing line 1090...
# Processing line 1100...
# Line 1108: 'Best animated film,2012,The Adventures of Tintin: Secret of the Unicorn,Steven Spielberg,"Animation, Jamie Bell, Andy Serkis ..."' not found in TSV file.
# Processing line 1110...
# Processing line 1120...
# Processing line 1130...
# Processing line 1140...
# Processing line 1150...
# Processing line 1160...
# Line 1166: 'Best tv series drama,1988,L.A. Law TV Series) (TV Series),"Steven Bochco (Creator), Terry Louise Fisher (Creator) ...","Jimmy Smits, Corbin Bernsen, Michele Greene ..."' not found in TSV file.
# Line 1167: 'Best tv series drama,1987,L.A. Law TV Series) (TV Series),"Steven Bochco (Creator), Terry Louise Fisher (Creator) ...","Jimmy Smits, Corbin Bernsen, Michele Greene ..."' not found in TSV file.
# Processing line 1170...
# Processing line 1180...
# Processing line 1190...
# Processing line 1200...
# Processing line 1210...
# Processing line 1220...
# Processing line 1230...
# Processing line 1240...
# Processing line 1250...
# Processing line 1260...
# Processing line 1270...
# Processing line 1280...
# Processing line 1290...
# Processing line 1300...
# Processing line 1310...
# Processing line 1320...
# Processing line 1330...
# Line 1338: 'Best leading actress tv series drama,1989,L.A. Law TV Series) (TV Series),"Steven Bochco (Creator), Terry Louise Fisher (Creator) ...","Jimmy Smits, Corbin Bernsen, Michele Greene ..."' not found in TSV file.
# Line 1339: 'Best leading actress tv series drama,1988,L.A. Law TV Series) (TV Series),"Steven Bochco (Creator), Terry Louise Fisher (Creator) ...","Jimmy Smits, Corbin Bernsen, Michele Greene ..."' not found in TSV file.
# Processing line 1340...
# Processing line 1350...
# Processing line 1360...
# Processing line 1370...
# Processing line 1380...
# Processing line 1390...
# Processing line 1400...
# Processing line 1410...
# Processing line 1420...
# Processing line 1430...
# Processing line 1440...
# Processing line 1450...
# Processing line 1460...
# Processing line 1470...
# Line 1475: 'Best miniseries tv,2023,The White Lotus 2 (TV Miniseries),"Mike White (Creator), Mike White","Michael Imperioli, Aubrey Plaza, F. Murray Abraham ..."' not found in TSV file.
# Processing line 1480...
# Line 1481: 'Best miniseries tv,2017,American Crime Story: The People v. O.J. Simpson (TV Miniseries),"Scott Alexander (Creator), Larry Karaszewski (Creator) ...","Cuba Gooding Jr., John Travolta, Sarah Paulson ..."' not found in TSV file.
# Processing line 1490...
# Processing line 1500...
# Processing line 1510...
# Processing line 1520...
# Processing line 1530...
# Line 1531: 'Best actor miniseries tv,2018,Fargo III (TV Miniseries),"Noah Hawley (Creator), Noah Hawley ...","Ewan McGregor, Carrie Coon, Mary Elizabeth Winstead ..."' not found in TSV file.
# Processing line 1540...
# Processing line 1550...
# Processing line 1560...
# Processing line 1570...
# Line 1575: 'Best actress miniseries tv,2017,American Crime Story: The People v. O.J. Simpson (TV Miniseries),"Scott Alexander (Creator), Larry Karaszewski (Creator) ...","Cuba Gooding Jr., John Travolta, Sarah Paulson ..."' not found in TSV file.
# Processing line 1580...
# Processing line 1590...
# Processing line 1600...
# Line 1605: 'Best actress miniseries tv,1987,Christmas Dove (TV),Stuart Cooper,"Loretta Young, Arthur Hill, Ron Leibman ..."' not found in TSV file.
# Processing line 1610...
# Processing line 1620...
# Processing line 1630...
# Processing line 1640...
# Processing line 1650...
# Processing line 1660...
# Line 1665: 'Best supporting actress series tv,2023,The White Lotus 2 (TV Miniseries),"Mike White (Creator), Mike White","Michael Imperioli, Aubrey Plaza, F. Murray Abraham ..."' not found in TSV file.
# Processing line 1670...
# Processing line 1680...
# Processing line 1690...
# Line 1696: 'Best supporting actress series tv,1992,L.A. Law TV Series) (TV Series),"Steven Bochco (Creator), Terry Louise Fisher (Creator) ...","Jimmy Smits, Corbin Bernsen, Michele Greene ..."' not found in TSV file.
# Processing line 1700...
# Processing line 1710...
# Total lines not found in TSV file: 27
# Lines not found in TSV file:
# Line 8: Best picture drama,2018,"Three Billboards Outside Ebbing, Missouri",Martin McDonagh,"Frances McDormand, Woody Harrelson, Sam Rockwell ..."
# Line 324: Best leading actress drama,2018,"Three Billboards Outside Ebbing, Missouri",Martin McDonagh,"Frances McDormand, Woody Harrelson, Sam Rockwell ..."
# Line 334: Best leading actress drama,2008,Away From Her,Sarah Polley,"Julie Christie, Gordon Pinsent, Olympia Dukakis ..."
# Line 396: Best leading actor comedy,2022,"tick, tick... Boom!",Lin-Manuel Miranda,"Andrew Garfield, Alexandra Shipp, Robin de Jesus ..."
# Line 510: Best leading actress comedy,1982,Pennies From Heaven,Herbert Ross,"Steve Martin, Christopher Walken, Bernadette Peters ..."
# Line 558: Best supporting actor,2018,"Three Billboards Outside Ebbing, Missouri",Martin McDonagh,"Frances McDormand, Woody Harrelson, Sam Rockwell ..."
# Line 587: Best supporting actor,1989,Tucker: the Man and His Dream,Francis Ford Coppola,"Jeff Bridges, Joan Allen, Martin Landau ..."
# Line 606: Best supporting actor,1970,"They Shoot Horses, Don't They?",Sydney Pollack,"Jane Fonda, Michael Sarrazin, Susannah York ..."
# Line 610: Best supporting actor,1966,The Spy Who Came In from the Cold,Martin Ritt,"Richard Burton, Claire Bloom, Oskar Werner ..."
# Line 662: Best supporting actress,1995,Bullets over Broadway,Woody Allen,"John Cusack, Dianne Wiest, Chazz Palminteri ..."
# Line 670: Best supporting actress,1987,A Room With a View,James Ivory,"Helena Bonham Carter, Maggie Smith, Denholm Elliott ..."
# Line 786: Best screenplay,2018,"Three Billboards Outside Ebbing, Missouri",Martin McDonagh,"Frances McDormand, Woody Harrelson, Sam Rockwell ..."
# Line 963: Best original song,1991,Young Guns 2: Blaze of Glory,Geoff Murphy,"Emilio Estévez, Kiefer Sutherland, Lou Diamond Phillips ..."
# Line 999: Best film promoting international unders,1956,Love is a Many-Splendored Thing,Henry King,"Jennifer Jones, William Holden, Isobel Elsom ..."
# Line 1026: Best foreign language film,2007,Letters From Iwo Jima,Clint Eastwood,"Ken Watanabe, Kazunari Ninomiya, Tsuyoshi Ihara ..."
# Line 1108: Best animated film,2012,The Adventures of Tintin: Secret of the Unicorn,Steven Spielberg,"Animation, Jamie Bell, Andy Serkis ..."
# Line 1166: Best tv series drama,1988,L.A. Law TV Series) (TV Series),"Steven Bochco (Creator), Terry Louise Fisher (Creator) ...","Jimmy Smits, Corbin Bernsen, Michele Greene ..."
# Line 1167: Best tv series drama,1987,L.A. Law TV Series) (TV Series),"Steven Bochco (Creator), Terry Louise Fisher (Creator) ...","Jimmy Smits, Corbin Bernsen, Michele Greene ..."
# Line 1338: Best leading actress tv series drama,1989,L.A. Law TV Series) (TV Series),"Steven Bochco (Creator), Terry Louise Fisher (Creator) ...","Jimmy Smits, Corbin Bernsen, Michele Greene ..."
# Line 1339: Best leading actress tv series drama,1988,L.A. Law TV Series) (TV Series),"Steven Bochco (Creator), Terry Louise Fisher (Creator) ...","Jimmy Smits, Corbin Bernsen, Michele Greene ..."
# Line 1475: Best miniseries tv,2023,The White Lotus 2 (TV Miniseries),"Mike White (Creator), Mike White","Michael Imperioli, Aubrey Plaza, F. Murray Abraham ..."
# Line 1481: Best miniseries tv,2017,American Crime Story: The People v. O.J. Simpson (TV Miniseries),"Scott Alexander (Creator), Larry Karaszewski (Creator) ...","Cuba Gooding Jr., John Travolta, Sarah Paulson ..."
# Line 1531: Best actor miniseries tv,2018,Fargo III (TV Miniseries),"Noah Hawley (Creator), Noah Hawley ...","Ewan McGregor, Carrie Coon, Mary Elizabeth Winstead ..."
# Line 1575: Best actress miniseries tv,2017,American Crime Story: The People v. O.J. Simpson (TV Miniseries),"Scott Alexander (Creator), Larry Karaszewski (Creator) ...","Cuba Gooding Jr., John Travolta, Sarah Paulson ..."
# Line 1605: Best actress miniseries tv,1987,Christmas Dove (TV),Stuart Cooper,"Loretta Young, Arthur Hill, Ron Leibman ..."
# Line 1665: Best supporting actress series tv,2023,The White Lotus 2 (TV Miniseries),"Mike White (Creator), Mike White","Michael Imperioli, Aubrey Plaza, F. Murray Abraham ..."
# Line 1696: Best supporting actress series tv,1992,L.A. Law TV Series) (TV Series),"Steven Bochco (Creator), Terry Louise Fisher (Creator) ...","Jimmy Smits, Corbin Bernsen, Michele Greene ..."

# %%
import pandas as pd

def search_and_save(csv_file1, csv_column1, csv_file2, csv_column2, output_csv):
    # Read the first CSV file and extract values from the specified column
    print("Reading first CSV file and extracting values...")
    csv_df1 = pd.read_csv(csv_file1)
    csv_values1 = csv_df1.iloc[:, csv_column1].astype(str).str.replace(r'\W', '').str.lower()
    print("Values extracted from the first CSV.")

    # Read the second CSV file and extract values from the specified column
    print("Reading second CSV file and extracting values...")
    csv_df2 = pd.read_csv(csv_file2)
    csv_values2 = csv_df2.iloc[:, csv_column2].astype(str).str.replace(r'\W', '').str.lower()
    print("Values extracted from the second CSV.")

    # Initialize a list to store lines where matches are found
    found_lines = []

    # Iterate through each value from the first CSV and search in the second CSV
    print("Searching for matches...")
    for i, csv_value1 in enumerate(csv_values1):
        # Check if csv_value1 exists in the second CSV
        if csv_value1 in csv_values2.values:
            print(f"Match found for value {csv_value1} at index {i}.")
            # Add the corresponding line from the first CSV to the list
            found_lines.append(csv_df1.iloc[i, :])

    # Write the found lines to a new CSV file
    found_df = pd.DataFrame(found_lines)
    found_df.to_csv(output_csv, index=False)
    print("Found lines saved to CSV.")

# Paths to the CSV files
csv_file1_path = "C:/Users/frivo/Downloads/camera_movies.csv"
csv_file2_path = "C:/Users/frivo/Downloads/found_lines_combined_film_festival_modified.csv"

# Output CSV file path
output_csv_path = 'found_lines_again.csv'

# Call the function
search_and_save(csv_file1_path, 0, csv_file2_path, 2, output_csv_path)
# Out:
# Reading first CSV file and extracting values...
# Values extracted from the first CSV.
# Reading second CSV file and extracting values...
# Values extracted from the second CSV.
# Searching for matches...
# Match found for value excalibur at index 52.
# Match found for value fitzcarraldo at index 84.
# Match found for value birdy at index 163.
# Match found for value police at index 196.
# Match found for value platoon at index 206.
# Match found for value caravaggio at index 218.
# Match found for value robocop at index 244.
# Match found for value brightness at index 271.
# Match found for value alice at index 376.
# Match found for value goodfellas at index 385.
# Match found for value cyclo at index 600.
# Match found for value shine at index 609.
# Match found for value fargo at index 625.
# Match found for value crash at index 630.
# Match found for value gattaca at index 730.
# Match found for value tango at index 762.
# Match found for value topsy-turvy at index 829.
# Match found for value magnolia at index 875.
# Match found for value election at index 891.
# Match found for value traffic at index 980.
# Match found for value vidocq at index 1054.
# Match found for value antitrust at index 1060.
# Match found for value monster at index 1214.
# Match found for value elephant at index 1215.
# Match found for value crash at index 1274.
# Match found for value monsters at index 1336.
# Match found for value bones at index 1392.
# Match found for value tsotsi at index 1467.
# Match found for value babel at index 1605.
# Match found for value chrysalis at index 1641.
# Match found for value australia at index 1861.
# Match found for value adoration at index 1925.
# Match found for value blindness at index 1927.
# Match found for value splice at index 1996.
# Match found for value home at index 1998.
# Match found for value zombieland at index 2041.
# Match found for value antichrist at index 2100.
# Match found for value precious at index 2143.
# Match found for value red at index 2170.
# Match found for value monsters at index 2258.
# Match found for value incendies at index 2281.
# Match found for value shame at index 2421.
# Match found for value faust at index 2430.
# Match found for value return at index 2525.
# Match found for value melancholia at index 2569.
# Match found for value tyrannosaur at index 2596.
# Match found for value priest at index 2630.
# Match found for value terraferma at index 2681.
# Match found for value drive at index 2682.
# Match found for value hell at index 2715.
# Match found for value thérèse at index 2769.
# Match found for value sister at index 2784.
# Match found for value antiviral at index 2959.
# Match found for value ida at index 3177.
# Match found for value philomena at index 3203.
# Match found for value oldboy at index 3280.
# Match found for value nebraska at index 3288.
# Match found for value trance at index 3364.
# Match found for value boyhood at index 3454.
# Match found for value leviathan at index 3552.
# Match found for value cake at index 3583.
# Match found for value foxcatcher at index 3626.
# Match found for value fargo at index 3631.
# Match found for value robocop at index 3686.
# Match found for value tailgate at index 3734.
# Match found for value anomalisa at index 3794.
# Match found for value room at index 3799.
# Match found for value hybrids at index 3876.
# Match found for value revenge at index 3895.
# Match found for value moonlight at index 3921.
# Match found for value jackie at index 3922.
# Match found for value oasis at index 4063.
# Match found for value ava at index 4072.
# Match found for value mandy at index 4122.
# Match found for value blackkklansman at index 4125.
# Match found for value monster at index 4133.
# Match found for value shoplifters at index 4158.
# Match found for value border at index 4166.
# Match found for value capernaum at index 4179.
# Match found for value sofia at index 4182.
# Match found for value parasite at index 4221.
# Match found for value atlantics at index 4248.
# Match found for value beginning at index 4283.
# Match found for value nomadland at index 4290.
# Match found for value kandahar at index 4362.
# Found lines saved to CSV.

# %%
import pandas as pd

# Read the CSV file with UTF-8 encoding
csv_file = "C:/Users/frivo/found_lines_golden_globes_award.csv"
with open(csv_file, 'r', encoding='utf-8') as file:
    lines = file.readlines()

# Split each line by comma and create a list of lists
data = [line.strip().split(',') for line in lines]

# Define column names
column_names = ['index', 'number', 'title', 'letter', 'letter_again', 'something', 'something_else', 'number_again','random']

# Create a DataFrame from the list of lists with specified column names
df = pd.DataFrame(data, columns=column_names)

# Save the DataFrame to the same CSV file, overwriting the existing file
df.to_csv(csv_file, index=False)

# %%
import pandas as pd

# Read the CSV file with UTF-8 encoding
csv_file = "C:/Users/frivo/found_lines_academy_award.csv"
with open(csv_file, 'r', encoding='utf-8') as file:
    lines = file.readlines()

# Split each line by comma and create a list of lists
data = [line.strip().split(',') for line in lines]

# Define column names
column_names = ['index', 'number', 'title', 'letter', 'letter_again', 'something', 'something_else', 'number_again','random']

# Create a DataFrame from the list of lists with specified column names
df = pd.DataFrame(data, columns=column_names)

# Save the DataFrame to the same CSV file, overwriting the existing file
df.to_csv(csv_file, index=False)

# %%
import pandas as pd

# Paths to the CSV files
csv_file1_path = "C:/Users/frivo/found_lines_golden_globes_award.csv"
csv_file2_path = "C:/Users/frivo/found_lines_academy_award.csv"

# Read both CSV files
csv_df1 = pd.read_csv(csv_file1_path, sep=',', header=None)
csv_df2 = pd.read_csv(csv_file2_path, sep=',', header=None)

# Concatenate both dataframes
combined_df = pd.concat([csv_df1, csv_df2], ignore_index=True)

# Output CSV file path
output_csv_path = 'C:/Users/frivo/found_lines_combined.csv'

# Save the combined dataframe to a new CSV file with comma-separated values
combined_df.to_csv(output_csv_path, index=False, header=False)

print("Combined CSV file saved successfully with comma-separated values on each line.")
# Out:
# Combined CSV file saved successfully with comma-separated values on each line.

# %%
import pandas as pd

def search_and_save(csv_file1, csv_column1, csv_file2, csv_column2, output_csv):
    # Read the first CSV file and extract values from the specified column
    print("Reading first CSV file and extracting values...")
    csv_df1 = pd.read_csv(csv_file1)
    csv_values1 = csv_df1.iloc[:, csv_column1].astype(str).str.replace(r'\W', '').str.lower()
    print("Values extracted from the first CSV.")

    # Read the second CSV file and extract values from the specified column
    print("Reading second CSV file and extracting values...")
    csv_df2 = pd.read_csv(csv_file2)
    csv_values2 = csv_df2.iloc[:, csv_column2].astype(str).str.replace(r'\W', '').str.lower()
    print("Values extracted from the second CSV.")

    # Initialize a list to store lines where matches are found
    found_lines = []

    # Iterate through each value from the first CSV and search in the second CSV
    print("Searching for matches...")
    for i, csv_value1 in enumerate(csv_values1):
        # Check if csv_value1 exists in the second CSV
        if csv_value1 in csv_values2.values:
            print(f"Match found for value {csv_value1} at index {i}.")
            # Add the corresponding line from the first CSV to the list
            found_lines.append(csv_df1.iloc[i, :])

    # Write the found lines to a new CSV file
    found_df = pd.DataFrame(found_lines)
    found_df.to_csv(output_csv, index=False)
    print("Found lines saved to CSV.")

# Paths to the CSV files
csv_file1_path = "C:/Users/frivo/Downloads/camera_movies.csv"
csv_file2_path = "C:/Users/frivo/found_lines_combined.csv"

# Output CSV file path
output_csv_path = 'found_lines.csv'

# Call the function
search_and_save(csv_file1_path, 0, csv_file2_path, 2, output_csv_path)
# Out:
# Reading first CSV file and extracting values...
# Values extracted from the first CSV.
# Reading second CSV file and extracting values...
# Values extracted from the second CSV.
# Searching for matches...
# Match found for value fame at index 21.
# Match found for value reds at index 63.
# Match found for value tootsie at index 98.
# Match found for value gandhi at index 105.
# Match found for value dune at index 151.
# Match found for value amadeus at index 166.
# Match found for value platoon at index 206.
# Match found for value castaway at index 216.
# Match found for value aliens at index 240.
# Match found for value robocop at index 244.
# Match found for value buster at index 303.
# Match found for value batman at index 318.
# Match found for value seinfeld at index 321.
# Match found for value ghost at index 363.
# Match found for value alice at index 376.
# Match found for value goodfellas at index 385.
# Match found for value jfk at index 395.
# Match found for value unforgiven at index 460.
# Match found for value speed at index 519.
# Match found for value friends at index 521.
# Match found for value babe at index 575.
# Match found for value braveheart at index 591.
# Match found for value casino at index 598.
# Match found for value shine at index 609.
# Match found for value emma at index 611.
# Match found for value fargo at index 625.
# Match found for value crash at index 630.
# Match found for value evita at index 656.
# Match found for value affliction at index 734.
# Match found for value tango at index 762.
# Match found for value elizabeth at index 805.
# Match found for value topsy-turvy at index 829.
# Match found for value magnolia at index 875.
# Match found for value gladiator at index 915.
# Match found for value u-571 at index 950.
# Match found for value pollock at index 960.
# Match found for value traffic at index 980.
# Match found for value chicago at index 1143.
# Match found for value pinocchio at index 1148.
# Match found for value frida at index 1158.
# Match found for value luther at index 1200.
# Match found for value monster at index 1214.
# Match found for value sideways at index 1270.
# Match found for value crash at index 1274.
# Match found for value ray at index 1282.
# Match found for value alfie at index 1285.
# Match found for value monsters at index 1336.
# Match found for value weeds at index 1371.
# Match found for value syriana at index 1416.
# Match found for value capote at index 1463.
# Match found for value tsotsi at index 1467.
# Match found for value babel at index 1605.
# Match found for value dreamgirls at index 1606.
# Match found for value once at index 1626.
# Match found for value juno at index 1701.
# Match found for value atonement at index 1741.
# Match found for value milk at index 1784.
# Match found for value departures at index 1930.
# Match found for value avatar at index 2092.
# Match found for value precious at index 2143.
# Match found for value burlesque at index 2193.
# Match found for value monsters at index 2258.
# Match found for value inception at index 2333.
# Match found for value lost at index 2350.
# Match found for value beginners at index 2371.
# Match found for value episodes at index 2379.
# Match found for value homeland at index 2399.
# Match found for value arthur at index 2412.
# Match found for value hugo at index 2528.
# Match found for value w.e. at index 2595.
# Match found for value boss at index 2793.
# Match found for value girls at index 2854.
# Match found for value kon-tiki at index 2873.
# Match found for value lincoln at index 2905.
# Match found for value skyfall at index 2912.
# Match found for value amour at index 2995.
# Match found for value argo at index 3007.
# Match found for value dexter at index 3101.
# Match found for value vice at index 3123.
# Match found for value helium at index 3174.
# Match found for value ida at index 3177.
# Match found for value her at index 3243.
# Match found for value gravity at index 3431.
# Match found for value interstellar at index 3449.
# Match found for value boyhood at index 3454.
# Match found for value whiplash at index 3459.
# Match found for value leviathan at index 3552.
# Match found for value selma at index 3574.
# Match found for value fargo at index 3631.
# Match found for value californication at index 3662.
# Match found for value robocop at index 3686.
# Match found for value empire at index 3732.
# Match found for value creed at index 3795.
# Match found for value joy at index 3797.
# Match found for value spotlight at index 3798.
# Match found for value room at index 3799.
# Match found for value spectre at index 3827.
# Match found for value entourage at index 3849.
# Match found for value luther at index 3883.
# Match found for value glee at index 3890.
# Match found for value arrival at index 3906.
# Match found for value moonlight at index 3921.
# Match found for value ben-hur at index 4044.
# Match found for value dunkirk at index 4096.
# Match found for value nashville at index 4114.
# Match found for value bodyguard at index 4121.
# Match found for value blackkklansman at index 4125.
# Match found for value monster at index 4133.
# Match found for value vice at index 4174.
# Match found for value bombshell at index 4200.
# Match found for value euphoria at index 4204.
# Match found for value parasite at index 4221.
# Match found for value julia at index 4225.
# Match found for value mank at index 4282.
# Match found for value nomadland at index 4290.
# Match found for value dune at index 4293.
# Match found for value oppenheimer at index 4354.
# Match found for value barbie at index 4374.
# Found lines saved to CSV.

# %%
import pandas as pd

# Paths to the CSV files
csv_file1_path = "C:/Users/frivo/found_lines.csv"
csv_file2_path = "C:/Users/frivo/found_lines_again.csv"

# Read both CSV files
csv_df1 = pd.read_csv(csv_file1_path, sep=',', header=None)
csv_df2 = pd.read_csv(csv_file2_path, sep=',', header=None)

# Concatenate both dataframes
combined_df = pd.concat([csv_df1, csv_df2], ignore_index=True)

# Output CSV file path
output_csv_path = 'C:/Users/frivo/grouped_merged_combined_festival_test'

# Save the combined dataframe to a new CSV file with comma-separated values
combined_df.to_csv(output_csv_path, index=False, header=False)

print("Combined CSV file saved successfully with comma-separated values on each line.")
# Out:
# Combined CSV file saved successfully with comma-separated values on each line.
